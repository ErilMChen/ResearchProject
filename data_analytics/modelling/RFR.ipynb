# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.impute import KNNImputer
import datetime as dt
import sqlite3

import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from patsy import dmatrices

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
# import xgboost as xg
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.tree import export_graphviz
from sklearn.datasets import make_classification
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.model_selection import cross_val_score
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
import joblib
from joblib import dump, load
import pickle
import bz2

import requests
import traceback
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, Float, String, DateTime

# import graphviz
# from graphviz import Source

# hide ipykernel warnings 
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("missforest_imputed_outliers_removed_all_features.csv")

# %%
df.head()
# Out:
#   ROUTEID  DIRECTION   temp  feels_like  temp_min  temp_max  pressure  \
# 0   102_8          1   9.81        5.49      8.69     10.00      1016
# 1   102_8          1   9.26        6.32      8.24     10.00      1016
# 2   102_8          1   9.76        5.50      8.43     10.00      1016
# 3   102_8          1  19.39       17.97     16.71     21.39      1027
# 4   102_8          1  13.93       14.14     13.00     15.00      1026
#
#    humidity  wind_speed  wind_deg  ...  HOUR_20  HOUR_21  HOUR_22  HOUR_23  \
# 0       100        6.17       240  ...        0        0        0        0
# 1        93        3.60       220  ...        0        0        0        0
# 2        93        5.66       240  ...        0        0        0        0
# 3        64        3.09       100  ...        0        0        0        0
# 4        94        1.03         0  ...        0        0        0        0
#
#    weekend_true_1  peak_true_1  HOUR_1  HOUR_2  JOURNEYTIME  PLANNED_JT
# 0               1            0       0       0         3391        3420
# 1               1            0       0       0         3659        3420
# 2               1            0       0       0         3490        3420
# 3               0            0       0       0         3800        3738
# 4               0            1       0       0         3582        3294
#
# [5 rows x 63 columns]

# %%
pd.set_option('display.max_rows', 70)
df.dtypes
# Out:
# ROUTEID                  object
# DIRECTION                 int64
# temp                    float64
# feels_like              float64
# temp_min                float64
# temp_max                float64
# pressure                  int64
# humidity                  int64
# wind_speed              float64
# wind_deg                  int64
# clouds_all                int64
# weather_main_Clouds       uint8
# weather_main_Drizzle      uint8
# weather_main_Fog          uint8
# weather_main_Mist         uint8
# weather_main_Rain         uint8
# weather_main_Smoke        uint8
# weather_main_Snow         uint8
# precipitation_true_1      uint8
# MONTH_1                   uint8
# MONTH_2                   uint8
# MONTH_3                   uint8
# MONTH_4                   uint8
# MONTH_5                   uint8
# MONTH_6                   uint8
# MONTH_7                   uint8
# MONTH_8                   uint8
# MONTH_9                   uint8
# MONTH_10                  uint8
# MONTH_11                  uint8
# WEEKDAY_1                 uint8
# WEEKDAY_2                 uint8
# WEEKDAY_3                 uint8
# WEEKDAY_4                 uint8
# WEEKDAY_5                 uint8
# WEEKDAY_6                 uint8
# HOUR_3                    uint8
# HOUR_4                    uint8
# HOUR_5                    uint8
# HOUR_6                    uint8
# HOUR_7                    uint8
# HOUR_8                    uint8
# HOUR_9                    uint8
# HOUR_10                   uint8
# HOUR_11                   uint8
# HOUR_12                   uint8
# HOUR_13                   uint8
# HOUR_14                   uint8
# HOUR_15                   uint8
# HOUR_16                   uint8
# HOUR_17                   uint8
# HOUR_18                   uint8
# HOUR_19                   uint8
# HOUR_20                   uint8
# HOUR_21                   uint8
# HOUR_22                   uint8
# HOUR_23                   uint8
# weekend_true_1            uint8
# peak_true_1               uint8
# HOUR_1                    uint8
# HOUR_2                    uint8
# JOURNEYTIME               int64
# PLANNED_JT                int64
# dtype: object

# %%
int_features = ["pressure", "humidity", "wind_deg", "clouds_all", "JOURNEYTIME", "PLANNED_JT"]

for feature in int_features:
    df[feature] = df[feature].astype("int64")
    
cat_features = ["weather_main_Clouds", "weather_main_Drizzle", "weather_main_Fog", "weather_main_Mist", "weather_main_Rain", "weather_main_Smoke", "weather_main_Snow", "MONTH_1", "MONTH_2", "MONTH_3", "MONTH_4", "MONTH_5", "MONTH_6", "MONTH_7", "MONTH_8", "MONTH_9", "MONTH_10", "MONTH_11", "WEEKDAY_1", "WEEKDAY_2", "WEEKDAY_3", "WEEKDAY_4", "WEEKDAY_5", "WEEKDAY_6", "HOUR_1", "HOUR_2", "HOUR_3", "HOUR_4", "HOUR_5", "HOUR_6", "HOUR_7", "HOUR_8", "HOUR_9", "HOUR_10", "HOUR_11", "HOUR_12", "HOUR_13", "HOUR_14", "HOUR_15", "HOUR_16", "HOUR_17", "HOUR_18", "HOUR_19", "HOUR_20", "HOUR_21", "HOUR_22", "HOUR_23", "precipitation_true_1", "weekend_true_1", "peak_true_1"]

for feature in cat_features:
    df[feature] = df[feature].astype("uint8")

# %%
# Create list of most common subroutes; these are the routes we will model
with open("most_common_subroutes.txt") as file:
    most_common_subroutes = file.readlines()
most_common_subroutes = [line.strip() for line in most_common_subroutes]

# %%
print(most_common_subroutes[:10])
# Out:
# ['102_8', '102_9', '104_15', '104_16', '111_7', '111_8', '114_5', '114_6', '116_1', '116_3']

# %%
df.columns
# Out:
# Index(['ROUTEID', 'DIRECTION', 'temp', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'humidity', 'wind_speed', 'wind_deg', 'clouds_all',
#        'weather_main_Clouds', 'weather_main_Drizzle', 'weather_main_Fog',
#        'weather_main_Mist', 'weather_main_Rain', 'weather_main_Smoke',
#        'weather_main_Snow', 'precipitation_true_1', 'MONTH_1', 'MONTH_2',
#        'MONTH_3', 'MONTH_4', 'MONTH_5', 'MONTH_6', 'MONTH_7', 'MONTH_8',
#        'MONTH_9', 'MONTH_10', 'MONTH_11', 'WEEKDAY_1', 'WEEKDAY_2',
#        'WEEKDAY_3', 'WEEKDAY_4', 'WEEKDAY_5', 'WEEKDAY_6', 'HOUR_3', 'HOUR_4',
#        'HOUR_5', 'HOUR_6', 'HOUR_7', 'HOUR_8', 'HOUR_9', 'HOUR_10', 'HOUR_11',
#        'HOUR_12', 'HOUR_13', 'HOUR_14', 'HOUR_15', 'HOUR_16', 'HOUR_17',
#        'HOUR_18', 'HOUR_19', 'HOUR_20', 'HOUR_21', 'HOUR_22', 'HOUR_23',
#        'weekend_true_1', 'peak_true_1', 'HOUR_1', 'HOUR_2', 'JOURNEYTIME',
#        'PLANNED_JT'],
#       dtype='object')

# %% [markdown]
# <p>We will examine those features rated as most important for a subset of routes, which will help us to choose the features we will use as input for our model.</p>

# %%
test = df.drop(["feels_like", "temp_min", "temp_max", "pressure", "clouds_all", "peak_true_1"], 1)

# %%
top_features = pd.DataFrame(columns=["feature", "importance"])
for route in most_common_subroutes[:10]:
    subset = test.loc[test["ROUTEID"] == route]

    y = pd.DataFrame(subset["JOURNEYTIME"])
    X = subset.drop(["JOURNEYTIME", "ROUTEID", "PLANNED_JT", "DIRECTION"], 1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

    rfr = RandomForestRegressor(n_estimators=100, max_features='auto', oob_score=True, random_state=1)
    rfr.fit(X_train, y_train)

    importance = pd.DataFrame({"feature": X_train.columns, "importance":rfr.feature_importances_})
    importance.sort_values(by=["importance"], inplace=True, ascending=False)
    importance_top_10 = importance.head(10)
    top_features = top_features.append(importance_top_10)

# %%
top_features.sort_values(by=["importance"], inplace=True, ascending=False)

# %%
pd.set_option("display.max_rows", 200)
top_features
# Out:
#               feature  importance
# 0                temp    0.426872
# 0                temp    0.263442
# 0                temp    0.199110
# 0                temp    0.188142
# 0                temp    0.169283
# 48            HOUR_22    0.156790
# 3            wind_deg    0.153131
# 1            humidity    0.143227
# 2          wind_speed    0.142757
# 0                temp    0.141775
# 0                temp    0.138185
# 3            wind_deg    0.127816
# 47            HOUR_21    0.126797
# 0                temp    0.123219
# 0                temp    0.118245
# 1            humidity    0.116741
# 2          wind_speed    0.116455
# 3            wind_deg    0.111107
# 46            HOUR_20    0.110280
# 50     weekend_true_1    0.109258
# 3            wind_deg    0.106482
# 1            humidity    0.106342
# 42            HOUR_16    0.102667
# 2          wind_speed    0.100702
# 2          wind_speed    0.099541
# 1            humidity    0.095357
# 0                temp    0.091976
# 3            wind_deg    0.086965
# 31             HOUR_5    0.080964
# 2          wind_speed    0.077292
# 1            humidity    0.074328
# 3            wind_deg    0.073077
# 46            HOUR_20    0.072110
# 3            wind_deg    0.069876
# 2          wind_speed    0.067724
# 3            wind_deg    0.066922
# 48            HOUR_22    0.066738
# 1            humidity    0.066276
# 46            HOUR_20    0.065495
# 45            HOUR_19    0.065239
# 50     weekend_true_1    0.064918
# 45            HOUR_19    0.064804
# 2          wind_speed    0.064581
# 49            HOUR_23    0.064380
# 3            wind_deg    0.064155
# 2          wind_speed    0.062647
# 2          wind_speed    0.061631
# 19            MONTH_8    0.060465
# 50     weekend_true_1    0.058064
# 3            wind_deg    0.057867
# 47            HOUR_21    0.057291
# 18            MONTH_7    0.056312
# 1            humidity    0.055699
# 17            MONTH_6    0.055463
# 30             HOUR_4    0.052069
# 1            humidity    0.051794
# 19            MONTH_8    0.050295
# 26          WEEKDAY_4    0.049160
# 41            HOUR_15    0.049011
# 1            humidity    0.048525
# 27          WEEKDAY_5    0.047122
# 2          wind_speed    0.046568
# 42            HOUR_16    0.045713
# 50     weekend_true_1    0.045701
# 33             HOUR_7    0.045569
# 42            HOUR_16    0.045096
# 32             HOUR_6    0.044247
# 1            humidity    0.043865
# 49            HOUR_23    0.043285
# 33             HOUR_7    0.042045
# 48            HOUR_22    0.041212
# 44            HOUR_18    0.040577
# 46            HOUR_20    0.039874
# 44            HOUR_18    0.038731
# 45            HOUR_19    0.038276
# 47            HOUR_21    0.038153
# 27          WEEKDAY_5    0.037894
# 46            HOUR_20    0.037836
# 34             HOUR_8    0.033810
# 45            HOUR_19    0.032224
# 22           MONTH_11    0.029428
# 46            HOUR_20    0.029334
# 20            MONTH_9    0.029203
# 45            HOUR_19    0.028877
# 31             HOUR_5    0.025809
# 8   weather_main_Rain    0.025068
# 13            MONTH_2    0.024852
# 47            HOUR_21    0.024727
# 47            HOUR_21    0.024522
# 13            MONTH_2    0.024444
# 18            MONTH_7    0.022992
# 45            HOUR_19    0.022760
# 40            HOUR_14    0.022412
# 46            HOUR_20    0.019954
# 20            MONTH_9    0.019804
# 34             HOUR_8    0.018751
# 21           MONTH_10    0.018573
# 33             HOUR_7    0.018535
# 20            MONTH_9    0.018504
# 32             HOUR_6    0.017619

# %%
grouped = top_features.groupby("feature").mean()
grouped.sort_values(by=["importance"], inplace=True, ascending=False)
grouped
# Out:
#                    importance
# feature
# temp                 0.186025
# wind_deg             0.091740
# HOUR_22              0.088247
# wind_speed           0.083990
# humidity             0.080215
# weekend_true_1       0.069485
# HOUR_16              0.064492
# MONTH_6              0.055463
# MONTH_8              0.055380
# HOUR_21              0.054298
# HOUR_23              0.053833
# HOUR_20              0.053555
# HOUR_5               0.053386
# HOUR_4               0.052069
# WEEKDAY_4            0.049160
# HOUR_15              0.049011
# WEEKDAY_5            0.042508
# HOUR_19              0.042030
# HOUR_18              0.039654
# MONTH_7              0.039652
# HOUR_7               0.035383
# HOUR_6               0.030933
# MONTH_11             0.029428
# HOUR_8               0.026281
# weather_main_Rain    0.025068
# MONTH_2              0.024648
# MONTH_9              0.022504
# HOUR_14              0.022412
# MONTH_10             0.018573

# %%
df.columns
# Out:
# Index(['ROUTEID', 'DIRECTION', 'temp', 'feels_like', 'temp_min', 'temp_max',
#        'pressure', 'humidity', 'wind_speed', 'wind_deg', 'clouds_all',
#        'weather_main_Clouds', 'weather_main_Drizzle', 'weather_main_Fog',
#        'weather_main_Mist', 'weather_main_Rain', 'weather_main_Smoke',
#        'weather_main_Snow', 'precipitation_true_1', 'MONTH_1', 'MONTH_2',
#        'MONTH_3', 'MONTH_4', 'MONTH_5', 'MONTH_6', 'MONTH_7', 'MONTH_8',
#        'MONTH_9', 'MONTH_10', 'MONTH_11', 'WEEKDAY_1', 'WEEKDAY_2',
#        'WEEKDAY_3', 'WEEKDAY_4', 'WEEKDAY_5', 'WEEKDAY_6', 'HOUR_3', 'HOUR_4',
#        'HOUR_5', 'HOUR_6', 'HOUR_7', 'HOUR_8', 'HOUR_9', 'HOUR_10', 'HOUR_11',
#        'HOUR_12', 'HOUR_13', 'HOUR_14', 'HOUR_15', 'HOUR_16', 'HOUR_17',
#        'HOUR_18', 'HOUR_19', 'HOUR_20', 'HOUR_21', 'HOUR_22', 'HOUR_23',
#        'weekend_true_1', 'peak_true_1', 'HOUR_1', 'HOUR_2', 'JOURNEYTIME',
#        'PLANNED_JT'],
#       dtype='object')

# %%
copy = df.copy()

# %%
copy["rain_true_1"] = np.where((copy["weather_main_Rain"] == 1), 1, 0)

# %%
final_trimmed = copy.drop(["feels_like", "temp_min", "temp_max", "pressure", "clouds_all", "weather_main_Clouds", "weather_main_Drizzle", "weather_main_Fog", "weather_main_Mist", "weather_main_Rain", "weather_main_Smoke", "weather_main_Snow", "precipitation_true_1"], 1)

# %%
# Function to perform random forest regression, dump regressors to pickle files and return a dataframe of metrics for each regressor
def RFR_prediction(df, route_list):
    model_metrics = pd.DataFrame(columns=["model_type", "data", "route", "MAE_test", "MSE_test", "RMSE_test", "MAPE_test", "R2_test", "MAE_actual_vs_planned", "MAPE_actual_vs_planned"])
    
    for route in route_list:
        print("ROUTE", route)
        current = df.loc[df["ROUTEID"] == route]
        current.drop(["ROUTEID"], axis = 1, inplace=True)
        direction = int(current.iloc[0]["DIRECTION"])
        line = route.split("_")[0]

        y = pd.DataFrame(current["JOURNEYTIME"])
        X = current.drop(["JOURNEYTIME", "DIRECTION"], 1)

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
        
        df_PLANNED_JT = X_test[["PLANNED_JT"]]

        X_train.drop(["PLANNED_JT"], axis=1, inplace=True)
        X_test.drop(["PLANNED_JT"], axis=1, inplace=True)
        
        rfr = RandomForestRegressor(n_estimators=100, max_features="auto", oob_score=True, random_state=1)
           
        rfr.fit(X_train, y_train)
        
#         pickle_filename = "pickles/{}_{}.pickle"
        compressed_filename = ("final_rfr_joblib/{}_{}.pickle".format(line, direction))
        
        joblib.dump(rfr, compressed_filename, compress=("bz2", 7))
        
#         pickle.dump(rfr, open(pickle_filename.format(line, direction), "wb"))
#         compressed_pickle = bz2.compress(open(pickle_filename.format(line, direction), "rb").read())
        
#         compressed_file = open(compressed_filename.format(line, direction), "wb")
#         compressed_file.write(compressed_pickle)
#         compressed_file.close()

        rfr_predictions_train = rfr.predict(X_train) 
        rfr_predictions_test = rfr.predict(X_test)
        
#         param_grid = {"n_estimators":[150, 200], "max_depth":[10, 20, 30], "min_samples_split":[6, 8, 10, 12], "min_samples_leaf":[1, 2]}
        
#         grid = HalvingGridSearchCV(rfr, param_grid, scoring="neg_mean_absolute_error", random_state=1, n_jobs=8).fit(X, y.values.ravel())
        
#         print(route)
#         print(abs(grid.best_score_))
#         print(grid.best_params_, "\n")
#         print('Training set score: ' + str(grid.score(X_train, y_train)))
#         print('Test set score: ' + str(grid.score(X_test, y_test)))
        
#         X_for_cross_val = X.drop(["PLANNED_JT"], axis=1)
        
#         scores = cross_val_score(rfr, X_for_cross_val, y, cv=5, scoring="neg_mean_absolute_error")
#         cross_val_mean = abs(scores.mean())

        mae_actual_vs_planned = metrics.mean_absolute_error(y_test, df_PLANNED_JT)
        mape_actual_vs_planned = metrics.mean_absolute_percentage_error(y_test, df_PLANNED_JT)

        mae_train = metrics.mean_absolute_error(y_train, rfr_predictions_train)
        mse_train = metrics.mean_squared_error(y_train, rfr_predictions_train)
        rmse_train = mse_train**0.5
        r2_train = metrics.r2_score(y_train, rfr_predictions_train)
        mape_train = metrics.mean_absolute_percentage_error(y_train, rfr_predictions_train)

        mae_test = metrics.mean_absolute_error(y_test, rfr_predictions_test)
        mse_test = metrics.mean_squared_error(y_test, rfr_predictions_test)
        rmse_test = mse_test**0.5
        r2_test = metrics.r2_score(y_test, rfr_predictions_test)
        mape_test = metrics.mean_absolute_percentage_error(y_test, rfr_predictions_test)

        new_row_model_metrics = {"model_type":"RFR", "data":"test", "route":route, "MAE_test":mae_test, "MSE_test":mse_test, "RMSE_test":rmse_test, "MAPE_test":mape_test, "R2_test":r2_test, "MAE_actual_vs_planned":mae_actual_vs_planned, "MAPE_actual_vs_planned":mape_actual_vs_planned}
        model_metrics = model_metrics.append(new_row_model_metrics, ignore_index=True)

        print("ROUTE", route)
        print("Number of entries:", current.shape[0], "\n")
        print("MAE train:", mae_train)
        print("MSE train:", mse_train)
        print("RMSE train:", rmse_train)
        print("MAPE train", mape_train)
        print("R2 train:", r2_train, "\n")
        print("MAE test:", mae_test)
        print("MSE test:", mse_test)
        print("RMSE test:", rmse_test)
        print("MAPE test", mape_test)
        print("R2 test:", r2_test, "\n")
#         print("Mean MAE from 5-fold cross-validation is:", cross_val_mean, "\n")
        print("MAE actual vs planned:", mae_actual_vs_planned)
        print("MAPE actual vs planned:", mape_actual_vs_planned)
        print("*************************")
    return model_metrics

# %%
test = RFR_prediction(final_trimmed, ["102_8"])
# Out:
# ROUTE 102_8
# ROUTE 102_8
# Number of entries: 9305
#
# MAE train: 148.84725303594163
# MSE train: 39632.31797213215
# RMSE train: 199.07867282090302
# MAPE train 0.042072617219024805
# R2 train: 0.8349864544466213
#
# MAE test: 280.76658518101607
# MSE test: 134196.97180674144
# RMSE test: 366.3290485434392
# MAPE test 0.0795142427058627
# R2 test: 0.45615927136368073
#
# MAE actual vs planned: 338.4297994269341
# MAPE actual vs planned: 0.09286484894944758
# *************************

# %%
test
# Out:
#   model_type  data  route    MAE_test       MSE_test   RMSE_test  MAPE_test  \
# 0        RFR  test  102_8  280.766585  134196.971807  366.329049   0.079514
#
#     R2_test  MAE_actual_vs_planned  MAPE_actual_vs_planned
# 0  0.456159             338.429799                0.092865

# %%
test_metrics = RFR_prediction(df, ["102_8"])
# Out:
# ROUTE 102_8
# Number of entries: 9305
#
# MAE train: 148.68062463418153
# MSE train: 39601.94978271723
# RMSE train: 199.00238637442826
# MAPE train 0.042046097242493856
# R2 train: 0.8351128957668317
#
# MAE test: 281.5158629630577
# MSE test: 134027.65270534586
# RMSE test: 366.0978731232208
# MAPE test 0.07977400003342455
# R2 test: 0.4568454464854833
#
# Mean MAE from 5-fold cross-validation is: 276.65820823456795
#
# MAE actual vs planned: 338.4297994269341
# MAPE actual vs planned: 0.09286484894944758
# *************************

# %%
test_metrics
# Out:
#   model_type  data  route    MAE_test       MSE_test   RMSE_test  MAPE_test  \
# 0        RFR  test  102_8  281.515863  134027.652705  366.097873   0.079774
#
#     R2_test  5_fold_cv_MAE  MAE_actual_vs_planned  MAPE_actual_vs_planned
# 0  0.456845     276.658208             338.429799                0.092865

# %% [markdown]
# <p>Amongst the metrics returned is MAE for static vs actual. This is the mean absolute error for actual journey times versus planned journey times. The Dublin Bus journey planner uses static timetables, which correspond to the planned journey times in the historical data. Through comparing the MAE for our predictions to the MAE for actual versus planned, we can deduce whether our model and therefore our approach surpasses the approach currently used by Dublin Bus. In the dataframe above where we modelled for a single test route we can see that our MAE is lower than that for static versus actual and therefore the journey times predicted by our model are an improvement on those predicted through the current Dublin Bus journey planner.</p>

# %%
final_routes_metrics = RFR_prediction(final_trimmed, most_common_subroutes)
# Out:
# ROUTE 102_8
# Number of entries: 9305
#
# MAE train: 148.84725303594163
# MSE train: 39632.31797213215
# RMSE train: 199.07867282090302
# MAPE train 0.042072617219024805
# R2 train: 0.8349864544466213
#
# MAE test: 280.76658518101607
# MSE test: 134196.97180674144
# RMSE test: 366.3290485434392
# MAPE test 0.0795142427058627
# R2 test: 0.45615927136368073
#
# Mean MAE from 5-fold cross-validation is: 277.8607715357691
#
# MAE actual vs planned: 338.4297994269341
# MAPE actual vs planned: 0.09286484894944758
# *************************
# ROUTE 102_9
# Number of entries: 9052
#
# MAE train: 141.68084846272203
# MSE train: 35834.98936528083
# RMSE train: 189.3013189739597
# MAPE train 0.04171906143416166
# R2 train: 0.8548375759748311
#
# MAE test: 279.48433778227786
# MSE test: 126280.93433409756
# RMSE test: 355.3602880656441
# MAPE test 0.08322889664620459
# R2 test: 0.4959747119476947
#
# Mean MAE from 5-fold cross-validation is: 268.3090556176406
#
# MAE actual vs planned: 332.4337260677467
# MAPE actual vs planned: 0.09567262820553511
# *************************
# ROUTE 104_15
# Number of entries: 3651
#
# MAE train: 97.00848236417855
# MSE train: 19935.587735321646
# RMSE train: 141.19344083675293
# MAPE train 0.040987640270814404
# R2 train: 0.8573943888196243
#
# MAE test: 249.95043418708727
# MSE test: 116713.71075809294
# RMSE test: 341.633884089522
# MAPE test 0.10383316637992855
# R2 test: 0.25305129276866856
#
# Mean MAE from 5-fold cross-validation is: 241.05183016859374
#
# MAE actual vs planned: 257.4023722627737
# MAPE actual vs planned: 0.10417770835575112
# *************************
# ROUTE 104_16
# Number of entries: 3556
#
# MAE train: 83.44444756930494
# MSE train: 12369.203767577339
# RMSE train: 111.21692212778296
# MAPE train 0.03638551839096303
# R2 train: 0.8989264962905101
#
# MAE test: 221.64221180880978
# MSE test: 82228.32273083412
# RMSE test: 286.75481291659975
# MAPE test 0.09674360905252052
# R2 test: 0.30735099822211187
#
# Mean MAE from 5-fold cross-validation is: 225.0564292893377
#
# MAE actual vs planned: 258.65042174320524
# MAPE actual vs planned: 0.1073167562399705
# *************************
# ROUTE 111_7
# Number of entries: 3975
#
# MAE train: 81.0296908698778
# MSE train: 12566.958938030193
# RMSE train: 112.10244840336982
# MAPE train 0.03194491375651092
# R2 train: 0.945627746171037
#
# MAE test: 218.85223805532272
# MSE test: 89888.69983051131
# RMSE test: 299.8144423314383
# MAPE test 0.0850538398168216
# R2 test: 0.6242315254141979
#
# Mean MAE from 5-fold cross-validation is: 219.35449811320754
#
# MAE actual vs planned: 303.7770326906957
# MAPE actual vs planned: 0.11571638828589696
# *************************
# ROUTE 111_8
# Number of entries: 2877
#
# MAE train: 148.55623944361648
# MSE train: 33937.433913015404
# RMSE train: 184.22115490088376
# MAPE train 0.05172914667356789
# R2 train: 0.862896399787342
#
# MAE test: 408.0984027777778
# MSE test: 246916.8433025463
# RMSE test: 496.90727837549963
# MAPE test 0.14313924102890632
# R2 test: 0.018299253921380876
#
# Mean MAE from 5-fold cross-validation is: 408.12557100845413
#
# MAE actual vs planned: 607.0416666666666
# MAPE actual vs planned: 0.18237432691581784
# *************************
# ROUTE 114_5
# Number of entries: 4780
#
# MAE train: 86.82557092216244
# MSE train: 14946.827407724439
# RMSE train: 122.2572182234016
# MAPE train 0.04724702352247639
# R2 train: 0.8889361398017657
#
# MAE test: 199.5271006038166
# MSE test: 69643.2567368921
# RMSE test: 263.9000885503681
# MAPE test 0.10771586761683473
# R2 test: 0.4855279889069384
#
# Mean MAE from 5-fold cross-validation is: 194.591371657097
#
# MAE actual vs planned: 253.20571827057182
# MAPE actual vs planned: 0.13025965561466962
# *************************
# ROUTE 114_6
# Number of entries: 4812
#
# MAE train: 92.95606819199374
# MSE train: 17864.892279583855
# RMSE train: 133.65961349481697
# MAPE train 0.052409976587169234
# R2 train: 0.8766847355313637
#
# MAE test: 203.9778818647496
# MSE test: 75169.62333862188
# RMSE test: 274.1707922785027
# MAPE test 0.1165251352200732
# R2 test: 0.48364177222357585
#
# Mean MAE from 5-fold cross-validation is: 202.87202625967237
#
# MAE actual vs planned: 249.19459833795014
# MAPE actual vs planned: 0.13284187189876676
# *************************
# ROUTE 116_1
# Number of entries: 116
#
# MAE train: 164.5287654320988
# MSE train: 48721.90730740743
# RMSE train: 220.73039506920526
# MAPE train 0.04913580061252803
# R2 train: 0.8838727774834826
#
# MAE test: 332.4668571428571
# MSE test: 166680.29259999996
# RMSE test: 408.2649784147545
# MAPE test 0.10251490764641043
# R2 test: 0.5082864805141218
#
# Mean MAE from 5-fold cross-validation is: 401.3538188405797
#
# MAE actual vs planned: 527.8857142857142
# MAPE actual vs planned: 0.16217325126679044
# *************************
# ROUTE 116_3
# Number of entries: 109
#
# MAE train: 237.48842105263157
# MSE train: 88855.43187368418
# RMSE train: 298.08628259898876
# MAPE train 0.0421043313301561
# R2 train: 0.8896352926085123
#
# MAE test: 481.7381818181817
# MSE test: 391798.25127272715
# RMSE test: 625.9378972971098
# MAPE test 0.08584693033203611
# R2 test: 0.39679369717456303
#
# Mean MAE from 5-fold cross-validation is: 614.0227142857144
#
# MAE actual vs planned: 798.8787878787879
# MAPE actual vs planned: 0.13854651707163454
# *************************
# ROUTE 118_4
# Number of entries: 121
#
# MAE train: 146.53672033257746
# MSE train: 43788.50875236899
# RMSE train: 209.25703991113176
# MAPE train 0.03586672046343823
# R2 train: 0.7803837041938833
#
# MAE test: 324.55075804375804
# MSE test: 193976.8799572126
# RMSE test: 440.4280644523151
# MAPE test 0.08314991784376381
# R2 test: 0.17366228582365173
#
# Mean MAE from 5-fold cross-validation is: 335.0051476190476
#
# MAE actual vs planned: 395.8378378378378
# MAPE actual vs planned: 0.0961965954385582
# *************************
# ROUTE 11_40
# Number of entries: 12895
#
# MAE train: 347.29797566642924
# MSE train: 292307.318679214
# RMSE train: 540.6545280298816
# MAPE train 0.0699310603994321
# R2 train: 0.76628774999951
#
# MAE test: 584.3287895954523
# MSE test: 769621.9682677055
# RMSE test: 877.2810087239468
# MAPE test 0.1194274348700033
# R2 test: 0.3493182236133504
#
# Mean MAE from 5-fold cross-validation is: 522.6561108224377
#
# MAE actual vs planned: 1606.6205737916775
# MAPE actual vs planned: 0.2834790104027563
# *************************
# ROUTE 11_42
# Number of entries: 13270
#
# MAE train: 223.01065235479223
# MSE train: 91853.90519948895
# RMSE train: 303.0740919304864
# MAPE train 0.05189411335869538
# R2 train: 0.859749700688782
#
# MAE test: 390.52743274239504
# MSE test: 269254.2440300881
# RMSE test: 518.8971420523418
# MAPE test 0.09167912471050069
# R2 test: 0.5929389371336676
#
# Mean MAE from 5-fold cross-validation is: 388.73687930407533
#
# MAE actual vs planned: 489.9555388093444
# MAPE actual vs planned: 0.10889675148066673
# *************************
# ROUTE 120_7
# Number of entries: 12147
#
# MAE train: 103.23190066052442
# MSE train: 18752.452065110676
# RMSE train: 136.9395927594013
# MAPE train 0.06382088404169746
# R2 train: 0.7535781625405482
#
# MAE test: 170.87257136554956
# MSE test: 47327.35317305393
# RMSE test: 217.54850763232997
# MAPE test 0.10547830712757823
# R2 test: 0.3904356954817991
#
# Mean MAE from 5-fold cross-validation is: 162.13561901822044
#
# MAE actual vs planned: 189.90534979423867
# MAPE actual vs planned: 0.11072871821011972
# *************************
# ROUTE 120_9
# Number of entries: 12211
#
# MAE train: 88.42593110263564
# MSE train: 13272.473267624297
# RMSE train: 115.20622061166792
# MAPE train 0.06020951911953906
# R2 train: 0.7599865437149487
#
# MAE test: 150.4630585524601
# MSE test: 37016.170418157155
# RMSE test: 192.39586902570738
# MAPE test 0.10238394069685103
# R2 test: 0.36530347180891265
#
# Mean MAE from 5-fold cross-validation is: 140.741329359374
#
# MAE actual vs planned: 176.12800218340612
# MAPE actual vs planned: 0.1133492388422763
# *************************
# ROUTE 122_18
# Number of entries: 9609
#
# MAE train: 222.2539813501041
# MSE train: 82457.47465073707
# RMSE train: 287.1540956537745
# MAPE train 0.055221942320686244
# R2 train: 0.7501736882359584
#
# MAE test: 335.29990728247935
# MSE test: 179718.4856982202
# RMSE test: 423.93217110549676
# MAPE test 0.08376303328753258
# R2 test: 0.4391610701422136
#
# Mean MAE from 5-fold cross-validation is: 329.6161663652842
#
# MAE actual vs planned: 459.366285119667
# MAPE actual vs planned: 0.1095159908373746
# *************************
# ROUTE 122_20
# Number of entries: 9341
#
# MAE train: 222.27932367977436
# MSE train: 82024.91217971666
# RMSE train: 286.39991651485633
# MAPE train 0.053425163887547464
# R2 train: 0.7701031475841111
#
# MAE test: 348.7967696120524
# MSE test: 190461.91284047614
# RMSE test: 436.41942307884983
# MAPE test 0.08472889245048391
# R2 test: 0.4527490465321914
#
# Mean MAE from 5-fold cross-validation is: 333.9144970573444
#
# MAE actual vs planned: 485.78808419550484
# MAPE actual vs planned: 0.11168190263685858
# *************************
# ROUTE 123_34
# Number of entries: 23741
#
# MAE train: 245.1448520431605
# MSE train: 99615.92912844948
# RMSE train: 315.61991243970886
# MAPE train 0.07000638957255634
# R2 train: 0.7365970435553151
#
# MAE test: 348.5040769149521
# MSE test: 197909.3666869363
# RMSE test: 444.8700559567213
# MAPE test 0.09976236509307838
# R2 test: 0.47544948443846025
#
# Mean MAE from 5-fold cross-validation is: 349.11558028169367
#
# MAE actual vs planned: 377.41162431559735
# MAPE actual vs planned: 0.10339912099109876
# *************************
# ROUTE 123_36
# Number of entries: 23986
#
# MAE train: 237.86615063297083
# MSE train: 94720.54623811701
# RMSE train: 307.767032409446
# MAPE train 0.06656028644610334
# R2 train: 0.7318191596938339
#
# MAE test: 339.00615123398006
# MSE test: 188687.88173094107
# RMSE test: 434.38218394743245
# MAPE test 0.09558268471261527
# R2 test: 0.47347727396660844
#
# Mean MAE from 5-fold cross-validation is: 344.26492327247854
#
# MAE actual vs planned: 398.7688993885492
# MAPE actual vs planned: 0.10680723757005535
# *************************
# ROUTE 130_10
# Number of entries: 26224
#
# MAE train: 110.21051852679787
# MSE train: 20044.04296973241
# RMSE train: 141.57698601726347
# MAPE train 0.06120088207284222
# R2 train: 0.7317266295901395
#
# MAE test: 154.83062134103645
# MSE test: 38451.48135025124
# RMSE test: 196.09049275844876
# MAPE test 0.08653467706192151
# R2 test: 0.479212707332316
#
# Mean MAE from 5-fold cross-validation is: 151.2114831533751
#
# MAE actual vs planned: 204.47114895780376
# MAPE actual vs planned: 0.10756219567885458
# *************************
# ROUTE 130_11
# Number of entries: 27057
#
# MAE train: 146.87385749534363
# MSE train: 35548.16940826078
# RMSE train: 188.54222181851145
# MAPE train 0.07927751643837637
# R2 train: 0.6650052292378457
#
# MAE test: 206.3964912479353
# MSE test: 68605.78419240491
# RMSE test: 261.92705891603663
# MAPE test 0.11200678378211763
# R2 test: 0.36661739863241105
#
# Mean MAE from 5-fold cross-validation is: 198.73325444883466
#
# MAE actual vs planned: 227.70128110372013
# MAPE actual vs planned: 0.11679066260742799
# *************************
# ROUTE 13_60
# Number of entries: 7662
#
# MAE train: 253.82203741606148
# MSE train: 114371.05415634911
# RMSE train: 338.18789770828454
# MAPE train 0.04045366025109464
# R2 train: 0.8011084520104639
#
# MAE test: 457.4433434484297
# MSE test: 355203.64830542717
# RMSE test: 595.9896377500428
# MAPE test 0.07274905282670403
# R2 test: 0.3969623547530663
#
# Mean MAE from 5-fold cross-validation is: 447.64213363421106
#
# MAE actual vs planned: 560.9090909090909
# MAPE actual vs planned: 0.08574445981575732
# *************************
# ROUTE 13_67
# Number of entries: 9107
#
# MAE train: 266.2135647048232
# MSE train: 125492.74838789676
# RMSE train: 354.24955665165874
# MAPE train 0.043498628115699246
# R2 train: 0.806815786186161
#
# MAE test: 473.65877548831423
# MSE test: 378888.7776585978
# RMSE test: 615.5394200687701
# MAPE test 0.07750196790561667
# R2 test: 0.40633389606700687
#
# Mean MAE from 5-fold cross-validation is: 459.2905690075465
#
# MAE actual vs planned: 556.3790706183681
# MAPE actual vs planned: 0.08771851176222743
# *************************
# ROUTE 140_19
# Number of entries: 21567
#
# MAE train: 198.5596493075959
# MSE train: 67795.72998394167
# RMSE train: 260.3761317477884
# MAPE train 0.055544927175604795
# R2 train: 0.7405827306118926
#
# MAE test: 291.6104979425219
# MSE test: 136860.9986372316
# RMSE test: 369.9472917014417
# MAPE test 0.08277286659002747
# R2 test: 0.4689007876411123
#
# Mean MAE from 5-fold cross-validation is: 298.16982770610906
#
# MAE actual vs planned: 349.70190078813164
# MAPE actual vs planned: 0.09522334079058752
# *************************
# ROUTE 140_21
# Number of entries: 19662
#
# MAE train: 328.28682637073075
# MSE train: 182779.6249090307
# RMSE train: 427.5273382007643
# MAPE train 0.0848751783843022
# R2 train: 0.6193410970850095
#
# MAE test: 494.34876874183436
# MSE test: 406978.64012582257
# RMSE test: 637.9487754716852
# MAPE test 0.1280661562759227
# R2 test: 0.1554196767231718
#
# Mean MAE from 5-fold cross-validation is: 479.920782944855
#
# MAE actual vs planned: 567.9416850313612
# MAPE actual vs planned: 0.13504947199587589
# *************************
# ROUTE 142_12
# Number of entries: 930
#
# MAE train: 166.11679626581815
# MSE train: 45409.65861561519
# RMSE train: 213.0954213858552
# MAPE train 0.028752957008492522
# R2 train: 0.7797132605284656
#
# MAE test: 321.3905093872674
# MSE test: 156637.47290069432
# RMSE test: 395.77452280395
# MAPE test 0.055666548160011826
# R2 test: 0.21338608379633273
#
# Mean MAE from 5-fold cross-validation is: 336.6115089947089
#
# MAE actual vs planned: 474.6953405017921
# MAPE actual vs planned: 0.07997839923562629
# *************************
# ROUTE 142_13
# Number of entries: 819
#
# MAE train: 207.25595328377264
# MSE train: 68811.26911028268
# RMSE train: 262.3190216325966
# MAPE train 0.03486495253054461
# R2 train: 0.708159881857053
#
# MAE test: 288.85858983270566
# MSE test: 138982.35828011588
# RMSE test: 372.8033775063148
# MAPE test 0.049532490502711655
# R2 test: 0.3996734773032149
#
# Mean MAE from 5-fold cross-validation is: 310.08254315468315
#
# MAE actual vs planned: 595.8617886178862
# MAPE actual vs planned: 0.09811736747140987
# *************************
# ROUTE 145_102
# Number of entries: 29023
#
# MAE train: 288.8638709890523
# MSE train: 136696.89003653548
# RMSE train: 369.7254251962333
# MAPE train 0.057647973362511346
# R2 train: 0.7614123406260587
#
# MAE test: 396.71070017819886
# MSE test: 255353.63113174087
# RMSE test: 505.32527260343994
# MAPE test 0.0793277233700134
# R2 test: 0.5645830649955663
#
# Mean MAE from 5-fold cross-validation is: 403.8779181223915
#
# MAE actual vs planned: 505.27472148845754
# MAPE actual vs planned: 0.09660186825021005
# *************************
# ROUTE 145_105
# Number of entries: 27685
#
# MAE train: 369.4184203910725
# MSE train: 226677.80509424547
# RMSE train: 476.1069261145499
# MAPE train 0.07084866421322514
# R2 train: 0.7300645856565481
#
# MAE test: 509.0994989496005
# MSE test: 421883.87956415355
# RMSE test: 649.5258882940337
# MAPE test 0.09822155897336814
# R2 test: 0.4846625983727135
#
# Mean MAE from 5-fold cross-validation is: 501.6788189990789
#
# MAE actual vs planned: 723.3649169275222
# MAPE actual vs planned: 0.12892109317685108
# *************************
# ROUTE 14C_17
# Number of entries: 238
#
# MAE train: 43.53205942818895
# MSE train: 3206.0105176037323
# RMSE train: 56.62164354382282
# MAPE train 0.03885453827023362
# R2 train: 0.874175305307628
#
# MAE test: 131.93114351851852
# MSE test: 27340.115398658174
# RMSE test: 165.34846657486176
# MAPE test 0.12322575193814167
# R2 test: -0.1762626333117725
#
# Mean MAE from 5-fold cross-validation is: 117.51950567375886
#
# MAE actual vs planned: 148.44444444444446
# MAPE actual vs planned: 0.13571664881925383
# *************************
# ROUTE 14C_18
# Number of entries: 582
#
# MAE train: 97.38122698022697
# MSE train: 18253.438218474905
# RMSE train: 135.10528567926167
# MAPE train 0.04554601614297282
# R2 train: 0.8283977399506495
#
# MAE test: 150.55286312925168
# MSE test: 37154.43277595339
# RMSE test: 192.7548514978375
# MAPE test 0.07028104483038505
# R2 test: 0.619167426798053
#
# Mean MAE from 5-fold cross-validation is: 170.321512118788
#
# MAE actual vs planned: 278.5542857142857
# MAPE actual vs planned: 0.11951335818944657
# *************************
# ROUTE 14_15
# Number of entries: 18173
#
# MAE train: 263.27655698223987
# MSE train: 119379.64652282234
# RMSE train: 345.51359817353404
# MAPE train 0.05417560792591016
# R2 train: 0.7996601219401978
#
# MAE test: 417.17643659563
# MSE test: 288527.5009315007
# RMSE test: 537.1475597370807
# MAPE test 0.08733910848467291
# R2 test: 0.5309077910912916
#
# Mean MAE from 5-fold cross-validation is: 414.01843087502476
#
# MAE actual vs planned: 476.34005869405723
# MAPE actual vs planned: 0.09587027990667217
# *************************
# ROUTE 14_16
# Number of entries: 17513
#
# MAE train: 250.11979549488817
# MSE train: 104933.02273844
# RMSE train: 323.9336702759378
# MAPE train 0.052071585389954524
# R2 train: 0.8110557282084574
#
# MAE test: 399.9970025704533
# MSE test: 266059.04514177033
# RMSE test: 515.8091169626322
# MAPE test 0.08366330810438671
# R2 test: 0.5313223118938488
#
# Mean MAE from 5-fold cross-validation is: 400.5085545500336
#
# MAE actual vs planned: 465.6855728968405
# MAPE actual vs planned: 0.09377242921659784
# *************************
# ROUTE 150_8
# Number of entries: 15213
#
# MAE train: 139.5686977297934
# MSE train: 34754.1398461971
# RMSE train: 186.4246224247138
# MAPE train 0.059394455160750384
# R2 train: 0.7828053606691775
#
# MAE test: 237.94679083790516
# MSE test: 97127.09033239106
# RMSE test: 311.65219449314174
# MAPE test 0.10201113523832057
# R2 test: 0.39869358293486956
#
# Mean MAE from 5-fold cross-validation is: 230.90139263253573
#
# MAE actual vs planned: 278.84180543382996
# MAPE actual vs planned: 0.11203967719079226
# *************************
# ROUTE 150_9
# Number of entries: 13678
#
# MAE train: 142.78150307557786
# MSE train: 34867.27096710427
# RMSE train: 186.72779912777924
# MAPE train 0.06011016286150925
# R2 train: 0.793430285044521
#
# MAE test: 248.35207811631457
# MSE test: 99584.32674264855
# RMSE test: 315.5698444760661
# MAPE test 0.10506972919249344
# R2 test: 0.3957942155966505
#
# Mean MAE from 5-fold cross-validation is: 240.5191047580669
#
# MAE actual vs planned: 366.6985867446394
# MAPE actual vs planned: 0.14454944656519145
# *************************
# ROUTE 151_15
# Number of entries: 12048
#
# MAE train: 196.10370987600686
# MSE train: 64640.00819803932
# RMSE train: 254.2439934355172
# MAPE train 0.04898986624677489
# R2 train: 0.8162923059057743
#
# MAE test: 323.76783322026824
# MSE test: 174934.81326848356
# RMSE test: 418.25209296366177
# MAPE test 0.08088498524355733
# R2 test: 0.4958722159772412
#
# Mean MAE from 5-fold cross-validation is: 323.16259975225495
#
# MAE actual vs planned: 397.9585062240664
# MAPE actual vs planned: 0.09525522682539833
# *************************
# ROUTE 151_17
# Number of entries: 13529
#
# MAE train: 183.09985603871957
# MSE train: 57239.945329749135
# RMSE train: 239.24871019453613
# MAPE train 0.04803200210640292
# R2 train: 0.83166370397601
#
# MAE test: 309.93857041724385
# MSE test: 159406.11814886925
# RMSE test: 399.256957545976
# MAPE test 0.08228853603327915
# R2 test: 0.5359626281828145
#
# Mean MAE from 5-fold cross-validation is: 316.51897503024037
#
# MAE actual vs planned: 410.20448386302047
# MAPE actual vs planned: 0.1032169074457529
# *************************
# ROUTE 15A_83
# Number of entries: 15623
#
# MAE train: 146.32197198969394
# MSE train: 37702.524942906784
# RMSE train: 194.17138033939705
# MAPE train 0.05920813337379592
# R2 train: 0.8751869035335232
#
# MAE test: 253.59672074131095
# MSE test: 111247.64599580184
# RMSE test: 333.53807278300604
# MAPE test 0.10348907093231033
# R2 test: 0.6324699764993804
#
# Mean MAE from 5-fold cross-validation is: 252.24516385532957
#
# MAE actual vs planned: 305.65969703435036
# MAPE actual vs planned: 0.11739053439175764
# *************************
# ROUTE 15A_84
# Number of entries: 12027
#
# MAE train: 168.8981893131287
# MSE train: 50413.53577872416
# RMSE train: 224.5295877578814
# MAPE train 0.05910531474684182
# R2 train: 0.8519941850387726
#
# MAE test: 289.1425116662608
# MSE test: 140085.54577827815
# RMSE test: 374.2800365745923
# MAPE test 0.10101140632839009
# R2 test: 0.583192640185221
#
# Mean MAE from 5-fold cross-validation is: 286.92004330557415
#
# MAE actual vs planned: 381.799944582987
# MAPE actual vs planned: 0.12620506157403857
# *************************
# ROUTE 15B_60
# Number of entries: 16669
#
# MAE train: 278.2336302586612
# MSE train: 142681.50875977305
# RMSE train: 377.73205948102026
# MAPE train 0.08309409731098141
# R2 train: 0.7103356245279313
#
# MAE test: 451.8438402806118
# MSE test: 352586.53693341697
# RMSE test: 593.7899771244181
# MAPE test 0.1367828440301604
# R2 test: 0.3048866031826397
#
# Mean MAE from 5-fold cross-validation is: 448.6898179414049
#
# MAE actual vs planned: 513.5402919416117
# MAPE actual vs planned: 0.14076145872448242
# *************************
# ROUTE 15B_61
# Number of entries: 12512
#
# MAE train: 189.8910405661363
# MSE train: 63494.80248525797
# RMSE train: 251.981750301997
# MAPE train 0.054649617516132926
# R2 train: 0.8455415993866486
#
# MAE test: 317.45201025320654
# MSE test: 167351.47496878085
# RMSE test: 409.0861461462376
# MAPE test 0.09228239549504617
# R2 test: 0.5749826435780055
#
# Mean MAE from 5-fold cross-validation is: 313.5170554270402
#
# MAE actual vs planned: 431.96403835908364
# MAPE actual vs planned: 0.11838452404863972
# *************************
# ROUTE 15D_62
# Number of entries: 410
#
# MAE train: 117.92554006968643
# MSE train: 24726.693682578396
# RMSE train: 157.24723744021196
# MAPE train 0.03535387191926412
# R2 train: 0.9096670921401322
#
# MAE test: 288.3083739837398
# MSE test: 143535.5548707317
# RMSE test: 378.8608647917223
# MAPE test 0.08188961945750123
# R2 test: 0.40319497497829226
#
# Mean MAE from 5-fold cross-validation is: 319.54841463414635
#
# MAE actual vs planned: 435.8617886178862
# MAPE actual vs planned: 0.11944473013866617
# *************************
# ROUTE 15D_63
# Number of entries: 181
#
# MAE train: 180.92603174603173
# MSE train: 55977.203069841264
# RMSE train: 236.59501911460703
# MAPE train 0.03969522448641674
# R2 train: 0.8746983248918744
#
# MAE test: 428.45309090909086
# MSE test: 304665.99782909086
# RMSE test: 551.9655766704033
# MAPE test 0.0956619104809716
# R2 test: 0.403840232641417
#
# Mean MAE from 5-fold cross-validation is: 477.8282117117118
#
# MAE actual vs planned: 596.2727272727273
# MAPE actual vs planned: 0.12435307116787495
# *************************
# ROUTE 15_16
# Number of entries: 22643
#
# MAE train: 461.139257933983
# MSE train: 345653.53216479137
# RMSE train: 587.9230665357427
# MAPE train 0.08624749206588589
# R2 train: 0.6037074543791905
#
# MAE test: 634.3589041049211
# MSE test: 643319.4149093886
# RMSE test: 802.0719512047461
# MAPE test 0.11872116652949961
# R2 test: 0.24522035556733257
#
# Mean MAE from 5-fold cross-validation is: 623.2306148535141
#
# MAE actual vs planned: 867.431767996467
# MAPE actual vs planned: 0.14725851241579554
# *************************
# ROUTE 15_17
# Number of entries: 28192
#
# MAE train: 385.5499387609768
# MSE train: 253268.41881075682
# RMSE train: 503.2578055139898
# MAPE train 0.07589248203620949
# R2 train: 0.6236831455034191
#
# MAE test: 517.4810448876717
# MSE test: 447355.15297616867
# RMSE test: 668.8461355021561
# MAPE test 0.10251873286654876
# R2 test: 0.3246113283069697
#
# Mean MAE from 5-fold cross-validation is: 515.6387650482993
#
# MAE actual vs planned: 594.6584298888627
# MAPE actual vs planned: 0.1109778065416222
# *************************
# ROUTE 161_50
# Number of entries: 94
#
# MAE train: 51.54153846153847
# MSE train: 4971.852960000004
# RMSE train: 70.51136759416885
# MAPE train 0.030059020222903115
# R2 train: 0.9491934522074711
#
# MAE test: 143.77275862068964
# MSE test: 33180.62884482758
# RMSE test: 182.15550731401888
# MAPE test 0.08909416232348563
# R2 test: 0.684794316821276
#
# Mean MAE from 5-fold cross-validation is: 137.92151461988303
#
# MAE actual vs planned: 419.3448275862069
# MAPE actual vs planned: 0.2330912441155599
# *************************
# ROUTE 161_51
# Number of entries: 194
#
# MAE train: 83.82173580246915
# MSE train: 11228.228161358023
# RMSE train: 105.96333404229041
# MAPE train 0.0727068808824925
# R2 train: 0.9406178364217044
#
# MAE test: 186.3089858757062
# MSE test: 52876.77753757862
# RMSE test: 229.94951084439955
# MAPE test 0.16354557148753904
# R2 test: 0.708220040274905
#
# Mean MAE from 5-fold cross-validation is: 195.71530442130972
#
# MAE actual vs planned: 549.3898305084746
# MAPE actual vs planned: 0.5423123525588168
# *************************
# ROUTE 16C_28
# Number of entries: 295
#
# MAE train: 73.23557732316227
# MSE train: 10189.21357028058
# RMSE train: 100.94163447398988
# MAPE train 0.03828438899546209
# R2 train: 0.9308068741808049
#
# MAE test: 201.18343699839485
# MSE test: 74430.80071755714
# RMSE test: 272.820088552066
# MAPE test 0.10901697262069054
# R2 test: 0.559124849160074
#
# Mean MAE from 5-fold cross-validation is: 184.773107102502
#
# MAE actual vs planned: 345.23595505617976
# MAPE actual vs planned: 0.18041144867107012
# *************************
# ROUTE 16C_29
# Number of entries: 561
#
# MAE train: 67.69468440233236
# MSE train: 7662.994519701743
# RMSE train: 87.53853162865906
# MAPE train 0.04229020642360738
# R2 train: 0.6819463042934679
#
# MAE test: 119.56366417770265
# MSE test: 21926.441311621475
# RMSE test: 148.07579583315254
# MAPE test 0.0745890351002519
# R2 test: 0.008328967066423942
#
# Mean MAE from 5-fold cross-validation is: 120.25842322895974
#
# MAE actual vs planned: 176.63313609467457
# MAPE actual vs planned: 0.10543158137158956
# *************************
# ROUTE 16D_30
# Number of entries: 83
#
# MAE train: 367.5360786808975
# MSE train: 198395.44991901136
# RMSE train: 445.4160413804282
# MAPE train 0.06410612773160766
# R2 train: 0.43593282942557576
#
# MAE test: 554.0992673015871
# MSE test: 461271.9974767864
# RMSE test: 679.1700799334335
# MAPE test 0.09944995315850584
# R2 test: -0.06002704709055484
#
# Mean MAE from 5-fold cross-validation is: 562.5334805613912
#
# MAE actual vs planned: 672.44
# MAPE actual vs planned: 0.1091781863919677
# *************************
# ROUTE 16_20
# Number of entries: 21150
#
# MAE train: 317.83580972006035
# MSE train: 166547.49664656058
# RMSE train: 408.1023114937731
# MAPE train 0.05819919328739561
# R2 train: 0.7621940280050014
#
# MAE test: 464.73789407735023
# MSE test: 348517.742054573
# RMSE test: 590.353912542784
# MAPE test 0.08621307845120135
# R2 test: 0.5152548152083523
#
# Mean MAE from 5-fold cross-validation is: 464.6810622408278
#
# MAE actual vs planned: 511.78534278959813
# MAPE actual vs planned: 0.09051913162628682
# *************************
# ROUTE 16_24
# Number of entries: 15471
#
# MAE train: 287.5801699638025
# MSE train: 138710.86069139634
# RMSE train: 372.4390697703402
# MAPE train 0.051765462048596056
# R2 train: 0.7713298910834426
#
# MAE test: 459.6118711044748
# MSE test: 336239.1071674498
# RMSE test: 579.86128269393
# MAPE test 0.08378967232023381
# R2 test: 0.4748554577377746
#
# Mean MAE from 5-fold cross-validation is: 459.9489864629342
#
# MAE actual vs planned: 573.3250753985351
# MAPE actual vs planned: 0.0993053632980019
# *************************
# ROUTE 17A_15
# Number of entries: 9842
#
# MAE train: 242.0586277519194
# MSE train: 97909.92148358129
# RMSE train: 312.90561114109363
# MAPE train 0.05364096574348468
# R2 train: 0.736898781810531
#
# MAE test: 389.3965247698552
# MSE test: 243279.59311935483
# RMSE test: 493.2338118168247
# MAPE test 0.08735888896592514
# R2 test: 0.33539562787658483
#
# Mean MAE from 5-fold cross-validation is: 374.25982512020573
#
# MAE actual vs planned: 435.91398577717575
# MAPE actual vs planned: 0.09403362753714868
# *************************
# ROUTE 17A_17
# Number of entries: 9998
#
# MAE train: 235.84431185389585
# MSE train: 95530.544744537
# RMSE train: 309.0801590923251
# MAPE train 0.0538529139411795
# R2 train: 0.7064878560357593
#
# MAE test: 385.96797468746996
# MSE test: 245234.55596633497
# RMSE test: 495.2116274547024
# MAPE test 0.088081922610204
# R2 test: 0.252435501041389
#
# Mean MAE from 5-fold cross-validation is: 360.82401411627177
#
# MAE actual vs planned: 437.9723333333333
# MAPE actual vs planned: 0.09594913255055743
# *************************
# ROUTE 17_10
# Number of entries: 7366
#
# MAE train: 158.50591798552497
# MSE train: 45448.35846518063
# RMSE train: 213.18620608562046
# MAPE train 0.04145860708044212
# R2 train: 0.9034622573644704
#
# MAE test: 318.4520361217214
# MSE test: 171749.94580049548
# RMSE test: 414.4272503111921
# MAPE test 0.08411083339910427
# R2 test: 0.644181190430823
#
# Mean MAE from 5-fold cross-validation is: 326.2796394614976
#
# MAE actual vs planned: 433.56244343891404
# MAPE actual vs planned: 0.11006124493803209
# *************************
# ROUTE 17_15
# Number of entries: 7948
#
# MAE train: 187.15102609645928
# MSE train: 66733.2965794191
# RMSE train: 258.32788579520235
# MAPE train 0.04695376187845641
# R2 train: 0.8943258424040401
#
# MAE test: 359.20286628232003
# MSE test: 218315.2659471444
# RMSE test: 467.242191959528
# MAPE test 0.09099873396601768
# R2 test: 0.635313550757576
#
# Mean MAE from 5-fold cross-validation is: 362.7563513620828
#
# MAE actual vs planned: 475.61006289308176
# MAPE actual vs planned: 0.12204054396445085
# *************************
# ROUTE 184_28
# Number of entries: 6902
#
# MAE train: 124.02087760765535
# MSE train: 31920.18618308544
# RMSE train: 178.66221252152187
# MAPE train 0.040755626103293745
# R2 train: 0.8246141327148391
#
# MAE test: 243.3999560588293
# MSE test: 110119.13277689202
# RMSE test: 331.8420298528986
# MAPE test 0.08008606040603376
# R2 test: 0.4261854520051723
#
# Mean MAE from 5-fold cross-validation is: 242.04674944833374
#
# MAE actual vs planned: 340.11492032834377
# MAPE actual vs planned: 0.1064972586416065
# *************************
# ROUTE 184_29
# Number of entries: 7579
#
# MAE train: 100.43510828508595
# MSE train: 18014.81090468805
# RMSE train: 134.219264283068
# MAPE train 0.03783220994971184
# R2 train: 0.8532960619680591
#
# MAE test: 194.76719573752985
# MSE test: 61601.273740031815
# RMSE test: 248.19603892897206
# MAPE test 0.07363697686991985
# R2 test: 0.49015737585480146
#
# Mean MAE from 5-fold cross-validation is: 190.03641768189306
#
# MAE actual vs planned: 244.2009674582234
# MAPE actual vs planned: 0.08904640482837294
# *************************
# ROUTE 185_53
# Number of entries: 2015
#
# MAE train: 44.53609219858156
# MSE train: 3178.3928204964536
# RMSE train: 56.37723672278071
# MAPE train 0.027844990486932616
# R2 train: 0.8668287149308925
#
# MAE test: 109.70895867768594
# MSE test: 19215.429200330578
# RMSE test: 138.61972875579644
# MAPE test 0.0678154412838998
# R2 test: 0.05881275089176907
#
# Mean MAE from 5-fold cross-validation is: 116.98549379652604
#
# MAE actual vs planned: 157.12561983471073
# MAPE actual vs planned: 0.0935580544820495
# *************************
# ROUTE 185_56
# Number of entries: 3422
#
# MAE train: 37.73798084302615
# MSE train: 2612.2564235708332
# RMSE train: 51.11023795259452
# MAPE train 0.03417670345350836
# R2 train: 0.9102295502316685
#
# MAE test: 95.4442338062781
# MSE test: 16097.817804913353
# RMSE test: 126.87717605981524
# MAPE test 0.0851785126593824
# R2 test: 0.44549610817641827
#
# Mean MAE from 5-fold cross-validation is: 95.99700972801023
#
# MAE actual vs planned: 121.70691333982474
# MAPE actual vs planned: 0.10309938233917486
# *************************
# ROUTE 18_3
# Number of entries: 8233
#
# MAE train: 191.86433974364752
# MSE train: 67248.95704125942
# RMSE train: 259.3240386876223
# MAPE train 0.049030089921928394
# R2 train: 0.8880577364785358
#
# MAE test: 387.6172224196856
# MSE test: 247928.86026787633
# RMSE test: 497.9245527867413
# MAPE test 0.09990365598058724
# R2 test: 0.5776653775419429
#
# Mean MAE from 5-fold cross-validation is: 390.7475255923515
#
# MAE actual vs planned: 480.3396761133603
# MAPE actual vs planned: 0.11786582084334433
# *************************
# ROUTE 18_4
# Number of entries: 12824
#
# MAE train: 224.49477535769773
# MSE train: 95924.38505860559
# RMSE train: 309.71662057210557
# MAPE train 0.05641019413834635
# R2 train: 0.8732128546389991
#
# MAE test: 377.79227968240474
# MSE test: 243710.9336943536
# RMSE test: 493.67087588225576
# MAPE test 0.09635564276358244
# R2 test: 0.6855411185112166
#
# Mean MAE from 5-fold cross-validation is: 386.8365494560097
#
# MAE actual vs planned: 467.47635135135135
# MAPE actual vs planned: 0.11464681621185527
# *************************
# ROUTE 1_37
# Number of entries: 14352
#
# MAE train: 165.63379402135018
# MSE train: 46917.19398608397
# RMSE train: 216.6037718648592
# MAPE train 0.055443409598142764
# R2 train: 0.7976711000899408
#
# MAE test: 268.5570047530204
# MSE test: 117163.24048081116
# RMSE test: 342.2911633110197
# MAPE test 0.09032213265307014
# R2 test: 0.4835949409161133
#
# Mean MAE from 5-fold cross-validation is: 269.8951205630684
#
# MAE actual vs planned: 332.5174175568973
# MAPE actual vs planned: 0.10698331717738171
# *************************
# ROUTE 1_40
# Number of entries: 14816
#
# MAE train: 183.15893965680607
# MSE train: 59040.7321999536
# RMSE train: 242.98298747022105
# MAPE train 0.05724875736212641
# R2 train: 0.7929998271146399
#
# MAE test: 298.85106549617115
# MSE test: 150284.04696695672
# RMSE test: 387.66486424095325
# MAPE test 0.09433571482510604
# R2 test: 0.4837279530708831
#
# Mean MAE from 5-fold cross-validation is: 306.11178687905897
#
# MAE actual vs planned: 357.4413948256468
# MAPE actual vs planned: 0.10747433668770631
# *************************
# ROUTE 220_10
# Number of entries: 2540
#
# MAE train: 127.50150168728909
# MSE train: 29881.11059510686
# RMSE train: 172.8615359040491
# MAPE train 0.027679505448749468
# R2 train: 0.9272763826516339
#
# MAE test: 321.4528740157481
# MSE test: 179380.03719120738
# RMSE test: 423.5328053305994
# MAPE test 0.06886711647827949
# R2 test: 0.5641469240960193
#
# Mean MAE from 5-fold cross-validation is: 339.73696062992127
#
# MAE actual vs planned: 469.65748031496065
# MAPE actual vs planned: 0.09704890573452381
# *************************
# ROUTE 220_12
# Number of entries: 2880
#
# MAE train: 112.04776785714286
# MSE train: 22651.560237499994
# RMSE train: 150.50435288555607
# MAPE train 0.025207535812227108
# R2 train: 0.9286617914877261
#
# MAE test: 302.67417824074073
# MSE test: 161336.06630497682
# RMSE test: 401.6666108913919
# MAPE test 0.06806829102336279
# R2 test: 0.5216454651811196
#
# Mean MAE from 5-fold cross-validation is: 299.7299930555556
#
# MAE actual vs planned: 501.681712962963
# MAPE actual vs planned: 0.10800972166945887
# *************************
# ROUTE 236_10
# Number of entries: 584
#
# MAE train: 59.22124999999999
# MSE train: 5769.079798284312
# RMSE train: 75.95445871233836
# MAPE train 0.029170130845000856
# R2 train: 0.8994800547439246
#
# MAE test: 162.63664772727273
# MSE test: 44156.60269602273
# RMSE test: 210.13472510754318
# MAPE test 0.07828151310349578
# R2 test: 0.08318764553943214
#
# Mean MAE from 5-fold cross-validation is: 158.34089493073975
#
# MAE actual vs planned: 393.5113636363636
# MAPE actual vs planned: 0.1859090033121011
# *************************
# ROUTE 236_9
# Number of entries: 660
#
# MAE train: 47.588679653679655
# MSE train: 3711.9917469696975
# RMSE train: 60.926117117125536
# MAPE train 0.024480671878930178
# R2 train: 0.8972955426045776
#
# MAE test: 110.60383838383837
# MSE test: 19786.106586868686
# RMSE test: 140.66309603754883
# MAPE test 0.05834180914554368
# R2 test: 0.34826796179303543
#
# Mean MAE from 5-fold cross-validation is: 120.28907575757576
#
# MAE actual vs planned: 571.7020202020202
# MAPE actual vs planned: 0.29598530209982876
# *************************
# ROUTE 238_11
# Number of entries: 4546
#
# MAE train: 55.422834695160276
# MSE train: 5321.405072344438
# RMSE train: 72.94796139951025
# MAPE train 0.03319046785731443
# R2 train: 0.9250363871438589
#
# MAE test: 151.72469941348973
# MSE test: 38853.9702648827
# RMSE test: 197.11410468275145
# MAPE test 0.09190015577171107
# R2 test: 0.45402798633937136
#
# Mean MAE from 5-fold cross-validation is: 150.0516654698437
#
# MAE actual vs planned: 225.983137829912
# MAPE actual vs planned: 0.1280996057427238
# *************************
# ROUTE 238_15
# Number of entries: 4483
#
# MAE train: 53.46474187380497
# MSE train: 4942.106564818356
# RMSE train: 70.30011781511007
# MAPE train 0.03377876878545511
# R2 train: 0.9148414033618087
#
# MAE test: 147.27453531598513
# MSE test: 36410.45710089219
# RMSE test: 190.81524336617395
# MAPE test 0.09286089723465644
# R2 test: 0.40508646782049074
#
# Mean MAE from 5-fold cross-validation is: 146.29355041109255
#
# MAE actual vs planned: 289.48624535315986
# MAPE actual vs planned: 0.16895184098759752
# *************************
# ROUTE 239_26
# Number of entries: 3239
#
# MAE train: 127.5565637406264
# MSE train: 34067.42672999559
# RMSE train: 184.5736349807187
# MAPE train 0.04459444472602473
# R2 train: 0.934768745400595
#
# MAE test: 348.3868930041152
# MSE test: 228722.55145884774
# RMSE test: 478.2494657172632
# MAPE test 0.11936775778050485
# R2 test: 0.5677752587275824
#
# Mean MAE from 5-fold cross-validation is: 340.0778961875322
#
# MAE actual vs planned: 732.7890946502058
# MAPE actual vs planned: 0.21839237217761134
# *************************
# ROUTE 239_28
# Number of entries: 3351
#
# MAE train: 155.1307590618337
# MSE train: 40392.54464857142
# RMSE train: 200.9789656868883
# MAPE train 0.051790518080142865
# R2 train: 0.881948370572208
#
# MAE test: 401.0324552683897
# MSE test: 264264.4197857853
# RMSE test: 514.0665519033361
# MAPE test 0.13415954463158386
# R2 test: 0.20901541058983564
#
# Mean MAE from 5-fold cross-validation is: 415.63200214427115
#
# MAE actual vs planned: 666.8429423459245
# MAPE actual vs planned: 0.19514694359362605
# *************************
# ROUTE 25A_270
# Number of entries: 14830
#
# MAE train: 155.1522046817493
# MSE train: 44997.765030528884
# RMSE train: 212.12676641699153
# MAPE train 0.0456914278577088
# R2 train: 0.8802271083753197
#
# MAE test: 266.87876087044185
# MSE test: 127249.32684404029
# RMSE test: 356.7202361011221
# MAPE test 0.07984487227395132
# R2 test: 0.6683397060965339
#
# Mean MAE from 5-fold cross-validation is: 264.6801919307476
#
# MAE actual vs planned: 345.71431782423014
# MAPE actual vs planned: 0.10000193802518124
# *************************
# ROUTE 25A_273
# Number of entries: 14234
#
# MAE train: 168.24120891442593
# MSE train: 50793.22707507936
# RMSE train: 225.37352789331618
# MAPE train 0.05163924176293712
# R2 train: 0.8534249362614775
#
# MAE test: 285.77414096454675
# MSE test: 134330.1439771097
# RMSE test: 366.5107692512045
# MAPE test 0.08961563561837836
# R2 test: 0.6107702075375707
#
# Mean MAE from 5-fold cross-validation is: 279.985027004509
#
# MAE actual vs planned: 368.4909857176305
# MAPE actual vs planned: 0.10912978094941284
# *************************
# ROUTE 25B_271
# Number of entries: 14268
#
# MAE train: 176.42607547712876
# MSE train: 59186.499123770016
# RMSE train: 243.28275550019984
# MAPE train 0.0483114482623252
# R2 train: 0.8674411940447608
#
# MAE test: 299.3120257161406
# MSE test: 155644.80105756508
# RMSE test: 394.51844197396537
# MAPE test 0.08331010892973031
# R2 test: 0.6463290824476811
#
# Mean MAE from 5-fold cross-validation is: 299.00722179619953
#
# MAE actual vs planned: 381.80401775286145
# MAPE actual vs planned: 0.10197529162989492
# *************************
# ROUTE 25B_274
# Number of entries: 14025
#
# MAE train: 159.14297977565144
# MSE train: 45326.75275073017
# RMSE train: 212.9008049555712
# MAPE train 0.0472377236203947
# R2 train: 0.8489260009360872
#
# MAE test: 271.94959543588675
# MSE test: 123625.42938343344
# RMSE test: 351.60408044195594
# MAPE test 0.08168083427317242
# R2 test: 0.5986292724481216
#
# Mean MAE from 5-fold cross-validation is: 273.68470708459074
#
# MAE actual vs planned: 372.361216730038
# MAPE actual vs planned: 0.10579919954110478
# *************************
# ROUTE 25D_275
# Number of entries: 545
#
# MAE train: 284.2401390971962
# MSE train: 130717.22181799116
# RMSE train: 361.5483671903265
# MAPE train 0.07830028591439549
# R2 train: 0.626120456759627
#
# MAE test: 540.9629518002322
# MSE test: 461040.6561226646
# RMSE test: 678.9997467765835
# MAPE test 0.14469920724071375
# R2 test: -0.05171362237713417
#
# Mean MAE from 5-fold cross-validation is: 500.04881821226684
#
# MAE actual vs planned: 498.0914634146341
# MAPE actual vs planned: 0.1276751230086218
# *************************
# ROUTE 25D_277
# Number of entries: 771
#
# MAE train: 147.63434101216245
# MSE train: 36675.03382809233
# RMSE train: 191.50726834272461
# MAPE train 0.04320900046462235
# R2 train: 0.7299005051356234
#
# MAE test: 297.9096531369732
# MSE test: 143747.54706104414
# RMSE test: 379.1405373486778
# MAPE test 0.08480320831210007
# R2 test: 0.06612912179953079
#
# Mean MAE from 5-fold cross-validation is: 293.0341315980742
#
# MAE actual vs planned: 381.71120689655174
# MAPE actual vs planned: 0.10365741785788603
# *************************
# ROUTE 25X_10
# Number of entries: 362
#
# MAE train: 126.68003952569168
# MSE train: 25025.052707905135
# RMSE train: 158.19308678923088
# MAPE train 0.02690991363447385
# R2 train: 0.8959182093801927
#
# MAE test: 314.1609174311927
# MSE test: 158393.46225688074
# RMSE test: 397.98676140907094
# MAPE test 0.06602203081469214
# R2 test: 0.29043758188581736
#
# Mean MAE from 5-fold cross-validation is: 355.817148021309
#
# MAE actual vs planned: 515.5412844036697
# MAPE actual vs planned: 0.1043539011288936
# *************************
# ROUTE 25X_11
# Number of entries: 167
#
# MAE train: 102.72525862068966
# MSE train: 17521.784792241386
# RMSE train: 132.36987871959914
# MAPE train 0.02319233805614431
# R2 train: 0.896771509777849
#
# MAE test: 230.94235294117647
# MSE test: 92286.15508235294
# RMSE test: 303.78636421398664
# MAPE test 0.0528402593191871
# R2 test: 0.43540780477558394
#
# Mean MAE from 5-fold cross-validation is: 266.79396791443844
#
# MAE actual vs planned: 409.29411764705884
# MAPE actual vs planned: 0.09188321056839849
# *************************
# ROUTE 25_269
# Number of entries: 5355
#
# MAE train: 83.4543703308431
# MSE train: 13073.559201547492
# RMSE train: 114.33966591497236
# MAPE train 0.03033871993384549
# R2 train: 0.952004825804814
#
# MAE test: 223.54163036714377
# MSE test: 94181.8795018046
# RMSE test: 306.8906637579654
# MAPE test 0.08219703466100926
# R2 test: 0.6591187572839337
#
# Mean MAE from 5-fold cross-validation is: 227.87804855275445
#
# MAE actual vs planned: 305.29371499688864
# MAPE actual vs planned: 0.1069051582133821
# *************************
# ROUTE 25_272
# Number of entries: 4928
#
# MAE train: 109.80918237170194
# MSE train: 20715.85123511163
# RMSE train: 143.93002200761185
# MAPE train 0.03826515762733976
# R2 train: 0.9386629181761547
#
# MAE test: 290.7852467883705
# MSE test: 142189.05643461796
# RMSE test: 377.0796420315183
# MAPE test 0.10033739428614034
# R2 test: 0.5818230866667162
#
# Mean MAE from 5-fold cross-validation is: 296.24046704008407
#
# MAE actual vs planned: 383.2163624070318
# MAPE actual vs planned: 0.12343002757584962
# *************************
# ROUTE 26_28
# Number of entries: 4538
#
# MAE train: 109.72882336396985
# MSE train: 23003.265990055876
# RMSE train: 151.66827614915348
# MAPE train 0.05306051023693089
# R2 train: 0.8342662762298831
#
# MAE test: 226.59845210707877
# MSE test: 88750.31364212232
# RMSE test: 297.909908600104
# MAPE test 0.10895287349121015
# R2 test: 0.356505509941045
#
# Mean MAE from 5-fold cross-validation is: 223.06437678873257
#
# MAE actual vs planned: 295.02863436123346
# MAPE actual vs planned: 0.13380664814966778
# *************************
# ROUTE 26_29
# Number of entries: 4710
#
# MAE train: 103.7635820659474
# MSE train: 20592.655782660313
# RMSE train: 143.50141386989995
# MAPE train 0.04769188525443846
# R2 train: 0.8946058577037111
#
# MAE test: 227.53774128556822
# MSE test: 90162.94228614842
# RMSE test: 300.27144767051766
# MAPE test 0.10785459450030935
# R2 test: 0.5490539200167668
#
# Mean MAE from 5-fold cross-validation is: 215.74511878222626
#
# MAE actual vs planned: 402.23000707714084
# MAPE actual vs planned: 0.17544656113210255
# *************************
# ROUTE 270_42
# Number of entries: 5673
#
# MAE train: 74.62308234701587
# MSE train: 9097.766927675648
# RMSE train: 95.3822149442738
# MAPE train 0.0543508734824825
# R2 train: 0.9033556655410918
#
# MAE test: 201.50499412455935
# MSE test: 65482.54044817862
# RMSE test: 255.895565510969
# MAPE test 0.14598333712513276
# R2 test: 0.31604326464916754
#
# Mean MAE from 5-fold cross-validation is: 201.3789383679463
#
# MAE actual vs planned: 300.4782608695652
# MAPE actual vs planned: 0.19011077678476374
# *************************
# ROUTE 270_44
# Number of entries: 5702
#
# MAE train: 73.98071160110248
# MSE train: 8379.74606474568
# RMSE train: 91.54095293771897
# MAPE train 0.05288285793689077
# R2 train: 0.8846622974237253
#
# MAE test: 205.71230859146698
# MSE test: 61849.867744827585
# RMSE test: 248.6963364121546
# MAPE test 0.14568836572016977
# R2 test: 0.11152692076411241
#
# Mean MAE from 5-fold cross-validation is: 204.39379048849116
#
# MAE actual vs planned: 251.23495032144945
# MAPE actual vs planned: 0.16084916289915815
# *************************
# ROUTE 27A_4
# Number of entries: 9259
#
# MAE train: 83.8269834148904
# MSE train: 12945.482466681262
# RMSE train: 113.77821613420234
# MAPE train 0.04475901625900146
# R2 train: 0.8893556619770082
#
# MAE test: 171.20054252802635
# MSE test: 49754.80009237556
# RMSE test: 223.05784023964628
# MAPE test 0.09262966279756897
# R2 test: 0.5745306466284696
#
# Mean MAE from 5-fold cross-validation is: 166.58686774404674
#
# MAE actual vs planned: 194.48596112311014
# MAPE actual vs planned: 0.10172093120036828
# *************************
# ROUTE 27A_5
# Number of entries: 9418
#
# MAE train: 94.18402721848338
# MSE train: 16305.269369270938
# RMSE train: 127.69208812323079
# MAPE train 0.046384899200355885
# R2 train: 0.8524389999880508
#
# MAE test: 187.97171994308673
# MSE test: 59632.148525209406
# RMSE test: 244.19694618321788
# MAPE test 0.09281446000618555
# R2 test: 0.4588513350112381
#
# Mean MAE from 5-fold cross-validation is: 183.5682758286888
#
# MAE actual vs planned: 238.14225053078556
# MAPE actual vs planned: 0.11217656347144624
# *************************
# ROUTE 27B_23
# Number of entries: 8763
#
# MAE train: 151.41670007276895
# MSE train: 40887.11111315302
# RMSE train: 202.2056159288189
# MAPE train 0.05603994666872189
# R2 train: 0.7951616245485573
#
# MAE test: 253.4089508571286
# MSE test: 105696.09193788217
# RMSE test: 325.10935381480823
# MAPE test 0.09357617529734115
# R2 test: 0.46320571684786005
#
# Mean MAE from 5-fold cross-validation is: 254.2033662963152
#
# MAE actual vs planned: 298.0688474705211
# MAPE actual vs planned: 0.10780844903690194
# *************************
# ROUTE 27B_34
# Number of entries: 11836
#
# MAE train: 147.27789030414027
# MSE train: 38653.27472889541
# RMSE train: 196.60436091016754
# MAPE train 0.05049948592780764
# R2 train: 0.7960193016131913
#
# MAE test: 241.16495336638704
# MSE test: 98639.25110595128
# RMSE test: 314.0688636365459
# MAPE test 0.08270998382656314
# R2 test: 0.4489144577885631
#
# Mean MAE from 5-fold cross-validation is: 237.1804592289378
#
# MAE actual vs planned: 300.7206420726556
# MAPE actual vs planned: 0.09846124468922961
# *************************
# ROUTE 27X_42
# Number of entries: 474
#
# MAE train: 126.99924471299094
# MSE train: 25820.707756193347
# RMSE train: 160.68823154230478
# MAPE train 0.02963468714994082
# R2 train: 0.9010945528586504
#
# MAE test: 318.2245454545455
# MSE test: 165951.5000384615
# RMSE test: 407.37145216431344
# MAPE test 0.07519073655988215
# R2 test: 0.18500420118646488
#
# Mean MAE from 5-fold cross-validation is: 343.6931621500559
#
# MAE actual vs planned: 434.56643356643355
# MAPE actual vs planned: 0.09748301674415051
# *************************
# ROUTE 27X_43
# Number of entries: 437
#
# MAE train: 181.69019703356753
# MSE train: 54556.054818718294
# RMSE train: 233.57237597523877
# MAPE train 0.04264460858182915
# R2 train: 0.6926542455214575
#
# MAE test: 347.3242308802309
# MSE test: 185920.30029551158
# RMSE test: 431.1847635243059
# MAPE test 0.08119113767807043
# R2 test: 0.28151419759491625
#
# Mean MAE from 5-fold cross-validation is: 343.2182205764542
#
# MAE actual vs planned: 530.3333333333334
# MAPE actual vs planned: 0.1195967978621659
# *************************
# ROUTE 27_17
# Number of entries: 23290
#
# MAE train: 376.53931151891516
# MSE train: 232374.1926304417
# RMSE train: 482.05206423211354
# MAPE train 0.061741367781036165
# R2 train: 0.7134549334127569
#
# MAE test: 543.1557518050089
# MSE test: 468801.05489501863
# RMSE test: 684.6904810898269
# MAPE test 0.08990402443297928
# R2 test: 0.4376753581405065
#
# Mean MAE from 5-fold cross-validation is: 534.759506144292
#
# MAE actual vs planned: 674.2375840847288
# MAPE actual vs planned: 0.10493908838289741
# *************************
# ROUTE 27_19
# Number of entries: 24079
#
# MAE train: 332.41636054629123
# MSE train: 183492.12449641165
# RMSE train: 428.3598072840304
# MAPE train 0.05473135883094232
# R2 train: 0.7924906819303489
#
# MAE test: 482.38547558794403
# MSE test: 380079.1239571912
# RMSE test: 616.5055749603496
# MAPE test 0.08016197738730749
# R2 test: 0.5734664308479747
#
# Mean MAE from 5-fold cross-validation is: 484.75605548602425
#
# MAE actual vs planned: 629.3153377630122
# MAPE actual vs planned: 0.09890124459252132
# *************************
# ROUTE 29A_14
# Number of entries: 15750
#
# ...
# R2 test: 0.5449223250860749
#
# Mean MAE from 5-fold cross-validation is: 460.97226206480684
#
# MAE actual vs planned: 665.982686008423
# MAPE actual vs planned: 0.13934647715503407
# *************************
# ROUTE 70_67
# Number of entries: 6661
#
# MAE train: 221.92846359635053
# MSE train: 109693.27068294658
# RMSE train: 331.1997443884077
# MAPE train 0.05443959833388315
# R2 train: 0.8404259374732695
#
# MAE test: 452.7791504476986
# MSE test: 361488.5937271506
# RMSE test: 601.239215060986
# MAPE test 0.11430331921889447
# R2 test: 0.48981137066531566
#
# Mean MAE from 5-fold cross-validation is: 435.79125464260596
#
# MAE actual vs planned: 578.295647823912
# MAPE actual vs planned: 0.1392057403493956
# *************************
# ROUTE 75_17
# Number of entries: 7914
#
# MAE train: 192.9151485150424
# MSE train: 76418.98317996517
# RMSE train: 276.4398364562625
# MAPE train 0.04331548700815426
# R2 train: 0.8896738986230515
#
# MAE test: 382.43569635923143
# MSE test: 276588.37473911303
# RMSE test: 525.9166994297794
# MAPE test 0.08659477297580193
# R2 test: 0.6242173970383054
#
# Mean MAE from 5-fold cross-validation is: 370.3682129439646
#
# MAE actual vs planned: 499.74021052631576
# MAPE actual vs planned: 0.1103401783455371
# *************************
# ROUTE 75_19
# Number of entries: 7809
#
# MAE train: 194.60699198363332
# MSE train: 68087.08356141055
# RMSE train: 260.9350178902988
# MAPE train 0.04253277054404146
# R2 train: 0.9012794046627778
#
# MAE test: 374.35957266833327
# MSE test: 234896.28301247337
# RMSE test: 484.66099803107056
# MAPE test 0.08316938020188536
# R2 test: 0.6455764361180998
#
# Mean MAE from 5-fold cross-validation is: 372.8974613698927
#
# MAE actual vs planned: 584.063593683312
# MAPE actual vs planned: 0.12308403719740763
# *************************
# ROUTE 76A_28
# Number of entries: 723
#
# MAE train: 203.7180830039526
# MSE train: 69183.50583458497
# RMSE train: 263.02757618657586
# MAPE train 0.04464288106596955
# R2 train: 0.8894692000722663
#
# MAE test: 502.22327188940096
# MSE test: 413677.06662903226
# RMSE test: 643.177321295638
# MAPE test 0.10922814227815375
# R2 test: 0.2504863460011172
#
# Mean MAE from 5-fold cross-validation is: 531.2975070881226
#
# MAE actual vs planned: 824.557603686636
# MAPE actual vs planned: 0.16189436944517957
# *************************
# ROUTE 76A_29
# Number of entries: 720
#
# MAE train: 147.43176587301588
# MSE train: 40915.39649464286
# RMSE train: 202.27554596303247
# MAPE train 0.033959428968161336
# R2 train: 0.9443383719678244
#
# MAE test: 381.09018518518525
# MSE test: 257788.18569166673
# RMSE test: 507.7284566494838
# MAPE test 0.08826178968706783
# R2 test: 0.665390899800566
#
# Mean MAE from 5-fold cross-validation is: 385.673125
#
# MAE actual vs planned: 563.2361111111111
# MAPE actual vs planned: 0.1229892262746408
# *************************
# ROUTE 76_36
# Number of entries: 11657
#
# MAE train: 181.24231218233803
# MSE train: 61274.25676044841
# RMSE train: 247.5363746208795
# MAPE train 0.0640412376595547
# R2 train: 0.8649229110651359
#
# MAE test: 339.33115402617995
# MSE test: 193318.82743330178
# RMSE test: 439.68036962468744
# MAPE test 0.1183322691730289
# R2 test: 0.568670242224506
#
# Mean MAE from 5-fold cross-validation is: 333.3611762808353
#
# MAE actual vs planned: 535.201829616924
# MAPE actual vs planned: 0.17023501846569536
# *************************
# ROUTE 76_37
# Number of entries: 11550
#
# MAE train: 127.94657972995877
# MSE train: 31945.684292060705
# RMSE train: 178.7335567039964
# MAPE train 0.04656388194828753
# R2 train: 0.8827831280269619
#
# MAE test: 238.731435633238
# MSE test: 102565.21276036433
# RMSE test: 320.25804089884195
# MAPE test 0.08763107039091758
# R2 test: 0.6188711143109078
#
# Mean MAE from 5-fold cross-validation is: 234.48984526887253
#
# MAE actual vs planned: 306.3575757575758
# MAPE actual vs planned: 0.10766729873681895
# *************************
# ROUTE 77A_28
# Number of entries: 13599
#
# MAE train: 242.3161817133635
# MSE train: 101652.79552556842
# RMSE train: 318.8303554016907
# MAPE train 0.05174008336465274
# R2 train: 0.8522647616554347
#
# MAE test: 391.18369391427615
# MSE test: 255101.82346241144
# RMSE test: 505.0760571066614
# MAPE test 0.08418809288868802
# R2 test: 0.6358092143491152
#
# Mean MAE from 5-fold cross-validation is: 386.8142480058878
#
# MAE actual vs planned: 507.8811274509804
# MAPE actual vs planned: 0.10481815207860319
# *************************
# ROUTE 77A_29
# Number of entries: 12909
#
# MAE train: 246.15752893191913
# MSE train: 106796.46286164071
# RMSE train: 326.7972809887511
# MAPE train 0.05263753234522542
# R2 train: 0.8675035512629379
#
# MAE test: 410.93405203711285
# MSE test: 285090.9864862381
# RMSE test: 533.9391224533356
# MAPE test 0.08841425582483614
# R2 test: 0.6426887367589601
#
# Mean MAE from 5-fold cross-validation is: 403.14577727293283
#
# MAE actual vs planned: 541.2414149238316
# MAPE actual vs planned: 0.11072349737278163
# *************************
# ROUTE 77X_61
# Number of entries: 198
#
# MAE train: 132.6605797101449
# MSE train: 30792.874868115938
# RMSE train: 175.4789869702807
# MAPE train 0.02284786430245191
# R2 train: 0.9194732201826648
#
# MAE test: 427.8834999999999
# MSE test: 336945.93030500005
# RMSE test: 580.4704387865071
# MAPE test 0.0729100324973452
# R2 test: 0.21090147497047362
#
# Mean MAE from 5-fold cross-validation is: 390.31953461538467
#
# MAE actual vs planned: 684.0833333333334
# MAPE actual vs planned: 0.11680050241088305
# *************************
# ROUTE 79A_27
# Number of entries: 8744
#
# MAE train: 91.77154804051249
# MSE train: 14737.592848206268
# RMSE train: 121.39848783327686
# MAPE train 0.04602110534079994
# R2 train: 0.8242641378571842
#
# MAE test: 180.39651693368242
# MSE test: 52188.847634922735
# RMSE test: 228.44878558425899
# MAPE test 0.0909412632884283
# R2 test: 0.39739895297190897
#
# Mean MAE from 5-fold cross-validation is: 172.44685760481826
#
# MAE actual vs planned: 238.0377286585366
# MAPE actual vs planned: 0.11377090535834403
# *************************
# ROUTE 79A_28
# Number of entries: 8269
#
# MAE train: 120.04124577713905
# MSE train: 27112.970206483755
# RMSE train: 164.6601658157909
# MAPE train 0.047051985578384074
# R2 train: 0.8705192534565455
#
# MAE test: 231.44770614927418
# MSE test: 94111.9101097592
# RMSE test: 306.7766453134254
# MAPE test 0.09231422450471158
# R2 test: 0.542932118534417
#
# Mean MAE from 5-fold cross-validation is: 237.28797613530642
#
# MAE actual vs planned: 373.43369609028616
# MAPE actual vs planned: 0.14044967497330044
# *************************
# ROUTE 79_10
# Number of entries: 11202
#
# MAE train: 104.35574422348543
# MSE train: 19637.873131003827
# RMSE train: 140.13519590382649
# MAPE train 0.052739664268578776
# R2 train: 0.8454576429733736
#
# MAE test: 195.63833202052837
# MSE test: 65227.92029233093
# RMSE test: 255.39757299616403
# MAPE test 0.10043166658121985
# R2 test: 0.49635929583091987
#
# Mean MAE from 5-fold cross-validation is: 191.20201722769232
#
# MAE actual vs planned: 225.1371615590598
# MAPE actual vs planned: 0.10965835599884635
# *************************
# ROUTE 79_11
# Number of entries: 11235
#
# MAE train: 131.20340238544165
# MSE train: 30545.095437830736
# RMSE train: 174.77155214116152
# MAPE train 0.05494259248470806
# R2 train: 0.8269462714787366
#
# MAE test: 240.10349689985847
# MSE test: 95639.461948679
# RMSE test: 309.25630462236177
# MAPE test 0.10154508076571955
# R2 test: 0.445285328576133
#
# Mean MAE from 5-fold cross-validation is: 237.7792588347987
#
# MAE actual vs planned: 346.7671314150104
# MAPE actual vs planned: 0.13680713053354085
# *************************
# ROUTE 7A_85
# Number of entries: 8615
#
# MAE train: 212.23479152452023
# MSE train: 75574.92928053431
# RMSE train: 274.90894725442155
# MAPE train 0.04791362421646784
# R2 train: 0.8587647228919234
#
# MAE test: 393.7472145482177
# MSE test: 251339.0478310502
# RMSE test: 501.3372595678983
# MAPE test 0.08940334442500024
# R2 test: 0.5388102459257076
#
# Mean MAE from 5-fold cross-validation is: 398.20272040232607
#
# MAE actual vs planned: 487.09400386847193
# MAPE actual vs planned: 0.1049721218832652
# *************************
# ROUTE 7A_87
# Number of entries: 6178
#
# MAE train: 214.181806928476
# MSE train: 77650.88620996734
# RMSE train: 278.6590859993037
# MAPE train 0.044808747958294926
# R2 train: 0.7709879221255445
#
# MAE test: 394.882988632472
# MSE test: 249900.33652935663
# RMSE test: 499.90032659456887
# MAPE test 0.08316349724805935
# R2 test: 0.2275171050619037
#
# Mean MAE from 5-fold cross-validation is: 400.31626623251054
#
# MAE actual vs planned: 540.4298813376483
# MAPE actual vs planned: 0.10785138769769725
# *************************
# ROUTE 7B_91
# Number of entries: 925
#
# MAE train: 205.69818459447123
# MSE train: 65817.91470753812
# RMSE train: 256.55002379173175
# MAPE train 0.04459122553415992
# R2 train: 0.47920618983011365
#
# MAE test: 282.5676611321333
# MSE test: 120104.3211868853
# RMSE test: 346.5607034660527
# MAPE test 0.06115712616579227
# R2 test: -0.023775416945682082
#
# Mean MAE from 5-fold cross-validation is: 282.1487252871153
#
# MAE actual vs planned: 407.46043165467626
# MAPE actual vs planned: 0.08521798523345545
# *************************
# ROUTE 7B_93
# Number of entries: 1216
#
# MAE train: 301.82408573183574
# MSE train: 165401.55870812465
# RMSE train: 406.69590446441015
# MAPE train 0.05669537304034842
# R2 train: 0.7620348616934136
#
# MAE test: 550.7533067732115
# MSE test: 470289.16274010675
# RMSE test: 685.7763212156765
# MAPE test 0.10483692908156032
# R2 test: 0.2729685882694035
#
# Mean MAE from 5-fold cross-validation is: 567.6176679026072
#
# MAE actual vs planned: 775.9753424657534
# MAPE actual vs planned: 0.1347893827521353
# *************************
# ROUTE 7D_120
# Number of entries: 236
#
# MAE train: 90.09939393939393
# MSE train: 13584.942301818184
# RMSE train: 116.55446066890012
# MAPE train 0.0217109676142369
# R2 train: 0.8483792555815683
#
# MAE test: 256.2391549295775
# MSE test: 100200.79165070425
# RMSE test: 316.54508628425157
# MAPE test 0.06153726085276715
# R2 test: 0.057725599864996036
#
# Mean MAE from 5-fold cross-validation is: 247.8380053191489
#
# MAE actual vs planned: 411.2535211267606
# MAPE actual vs planned: 0.09582253693783141
# *************************
# ROUTE 7D_123
# Number of entries: 201
#
# MAE train: 159.69478571428573
# MSE train: 38462.43149642858
# RMSE train: 196.1184119261335
# MAPE train 0.03711977902989918
# R2 train: 0.866592820850563
#
# MAE test: 520.777868852459
# MSE test: 358139.43268032785
# RMSE test: 598.4475187352086
# MAPE test 0.12719630340996424
# R2 test: -0.1832893945799201
#
# Mean MAE from 5-fold cross-validation is: 497.5781999999999
#
# MAE actual vs planned: 707.9672131147541
# MAPE actual vs planned: 0.1590031861412804
# *************************
# ROUTE 7_70
# Number of entries: 6569
#
# MAE train: 234.22533473145674
# MSE train: 94793.12130893426
# RMSE train: 307.8849156891813
# MAPE train 0.05342785126955153
# R2 train: 0.7621441751670833
#
# MAE test: 470.84268346379645
# MSE test: 361868.88757717237
# RMSE test: 601.5553902818696
# MAPE test 0.10598096421816144
# R2 test: 0.11751960907128356
#
# Mean MAE from 5-fold cross-validation is: 456.6020120100775
#
# MAE actual vs planned: 594.1887366818873
# MAPE actual vs planned: 0.12595246025488063
# *************************
# ROUTE 83_16
# Number of entries: 14896
#
# MAE train: 277.46084253925
# MSE train: 136156.86400804526
# RMSE train: 368.99439563229856
# MAPE train 0.05622590378176882
# R2 train: 0.8046294541120926
#
# MAE test: 437.98556070119554
# MSE test: 321597.6953205631
# RMSE test: 567.0958431522515
# MAPE test 0.08929944513251858
# R2 test: 0.5426374648600734
#
# Mean MAE from 5-fold cross-validation is: 449.6280455491395
#
# MAE actual vs planned: 509.5867084358917
# MAPE actual vs planned: 0.10006621662420201
# *************************
# ROUTE 83_22
# Number of entries: 14001
#
# MAE train: 288.1290415647504
# MSE train: 145880.76516503093
# RMSE train: 381.9434057095775
# MAPE train 0.06118628556248124
# R2 train: 0.7327620655746709
#
# MAE test: 471.808891326928
# MSE test: 375453.9536281395
# RMSE test: 612.7429751764923
# MAPE test 0.10042273717622996
# R2 test: 0.3221870184762139
#
# Mean MAE from 5-fold cross-validation is: 460.4832641886368
#
# MAE actual vs planned: 510.6293739585813
# MAPE actual vs planned: 0.10407095530862778
# *************************
# ROUTE 84A_1
# Number of entries: 1378
#
# MAE train: 107.20819502074689
# MSE train: 20765.202609958505
# RMSE train: 144.10136227655346
# MAPE train 0.037924322751008224
# R2 train: 0.933534890229212
#
# MAE test: 287.5399033816425
# MSE test: 146136.58856231882
# RMSE test: 382.2781560098861
# MAPE test 0.10392598729262426
# R2 test: 0.462571808897108
#
# Mean MAE from 5-fold cross-validation is: 290.90342168642957
#
# MAE actual vs planned: 334.77294685990336
# MAPE actual vs planned: 0.11594324197706571
# *************************
# ROUTE 84A_3
# Number of entries: 1531
#
# MAE train: 73.79140056022409
# MSE train: 9190.941043417366
# RMSE train: 95.86939576015573
# MAPE train 0.03064538967197596
# R2 train: 0.9142964576297661
#
# MAE test: 191.9155
# MSE test: 64518.250885
# RMSE test: 254.00443083733796
# MAPE test 0.07851682052373755
# R2 test: 0.42888311190611705
#
# Mean MAE from 5-fold cross-validation is: 195.04747241915226
#
# MAE actual vs planned: 281.9086956521739
# MAPE actual vs planned: 0.11367276313411924
# *************************
# ROUTE 84X_57
# Number of entries: 270
#
# MAE train: 241.0403625598387
# MSE train: 91938.08888492572
# RMSE train: 303.2129431355557
# MAPE train 0.043838675969840875
# R2 train: 0.7878244928776381
#
# MAE test: 547.1663091318832
# MSE test: 506212.21774566284
# RMSE test: 711.4859223805224
# MAPE test 0.09708475505286343
# R2 test: 0.1047238814799315
#
# Mean MAE from 5-fold cross-validation is: 563.2012731481482
#
# MAE actual vs planned: 612.679012345679
# MAPE actual vs planned: 0.10735850435738006
# *************************
# ROUTE 84X_62
# Number of entries: 1155
#
# MAE train: 238.1304373094246
# MSE train: 98856.2994856519
# RMSE train: 314.41421641785206
# MAPE train 0.04225630603038756
# R2 train: 0.797923662091254
#
# MAE test: 360.5303665358816
# MSE test: 215534.96305785107
# RMSE test: 464.25743188219514
# MAPE test 0.06501084882551061
# R2 test: 0.5213624697331891
#
# Mean MAE from 5-fold cross-validation is: 362.6495637749937
#
# MAE actual vs planned: 581.7118155619596
# MAPE actual vs planned: 0.10249583327513082
# *************************
# ROUTE 84_27
# Number of entries: 4243
#
# MAE train: 115.68973063973064
# MSE train: 24896.109940269358
# RMSE train: 157.78501177320157
# MAPE train 0.023349332807993218
# R2 train: 0.9468555613798676
#
# MAE test: 307.9934171249018
# MSE test: 168527.28350620583
# RMSE test: 410.52074674272654
# MAPE test 0.062489249330155004
# R2 test: 0.6196873065670685
#
# Mean MAE from 5-fold cross-validation is: 310.92072000077786
#
# MAE actual vs planned: 463.56637863315007
# MAPE actual vs planned: 0.09224270161602158
# *************************
# ROUTE 84_30
# Number of entries: 4428
#
# MAE train: 124.79671118563593
# MSE train: 29965.044465316307
# RMSE train: 173.10414340886328
# MAPE train 0.0256101885820927
# R2 train: 0.9374329552755732
#
# MAE test: 304.7996100809775
# MSE test: 160145.86206872112
# RMSE test: 400.1822860506461
# MAPE test 0.06304422955398482
# R2 test: 0.6673856687481519
#
# Mean MAE from 5-fold cross-validation is: 309.8897978705794
#
# MAE actual vs planned: 421.25959367945825
# MAPE actual vs planned: 0.0847844454124435
# *************************
# ROUTE 9_5
# Number of entries: 21158
#
# MAE train: 259.8870679176148
# MSE train: 114974.12425899133
# RMSE train: 339.07834531121466
# MAPE train 0.05460856326779641
# R2 train: 0.8050715732411379
#
# MAE test: 379.1742210157976
# MSE test: 238167.65266892596
# RMSE test: 488.0242336902195
# MAPE test 0.07982304569500291
# R2 test: 0.5909368423786312
#
# Mean MAE from 5-fold cross-validation is: 392.50555625584633
#
# MAE actual vs planned: 475.24511657214873
# MAPE actual vs planned: 0.09613618279425223
# *************************
# ROUTE 9_7
# Number of entries: 21095
#
# MAE train: 281.58895485594815
# MSE train: 133884.56278440193
# RMSE train: 365.90239516078867
# MAPE train 0.06088012182763922
# R2 train: 0.7308164977184279
#
# MAE test: 409.37992759584563
# MSE test: 277638.3808705633
# RMSE test: 526.9140165819878
# MAPE test 0.08969044984075018
# R2 test: 0.43187418222584784
#
# Mean MAE from 5-fold cross-validation is: 409.4533582498394
#
# MAE actual vs planned: 459.5128772317902
# MAPE actual vs planned: 0.09542095038103349
# *************************

# %%
final_routes_metrics.to_csv("rfr_final_metrics.csv", index=False)

# %%
final_routes_metrics = pd.read_csv("rfr_final_metrics.csv")

# %%
# Max MAE for predictions vs actual
final_routes_metrics["5_fold_cv_MAE"].max()
# Out:
# 692.3713367147424

# %%
# Min MAE for predictions vs actual
final_routes_metrics["5_fold_cv_MAE"].min()
# Out:
# 96.0856314070998

# %%
# Mean MAE for predictions vs actual
final_routes_metrics["5_fold_cv_MAE"].mean()
# Out:
# 319.8247101675142

# %%
# Max MAE for planned vs actual
final_routes_metrics.MAE_actual_vs_planned.max()
# Out:
# 1606.6205737916775

# %%
# Min MAE for planned vs actual
final_routes_metrics.MAE_actual_vs_planned.min()
# Out:
# 121.70691333982474

# %%
# Mean MAE for planned vs actual
final_routes_metrics.MAE_actual_vs_planned.mean()
# Out:
# 462.2779995944215

# %% [markdown]
# <p>Above we can see the min, max and mean MAE for predicted vs actual and planned vs actual. In creating these models the same input features were used when modelling for each route. It is believed that there would likely be further improvement if the input features were adjusted on a route by route basis. However, our predicted journey times are already more accurate than the Dublin Bus planned journey times and so our models are already a success.</p>

# %%
final_routes_metrics.loc[final_routes_metrics["MAE_actual_vs_planned"] < final_routes_metrics["5_fold_cv_MAE"]]
# Out:
#     model_type  data   route    MAE_test       MSE_test   RMSE_test  \
# 101        RFR  test  31D_51  325.155094  167420.291015  409.170247
# 132        RFR  test   39X_3  451.887513  309325.483154  556.170372
# 148        RFR  test  41D_26  460.755000  214026.146050  462.629599
# 216        RFR  test  70D_71  277.785000  132942.578906  364.612917
#
#      MAPE_test   R2_test  5_fold_cv_MAE  MAE_actual_vs_planned  \
# 101   0.142171  0.020935     381.957689             377.094340
# 132   0.108687 -0.169306     424.751329             378.861925
# 148   0.128751 -0.451458     561.080000             384.000000
# 216   0.084181  0.166327     301.087529             284.648148
#
#      MAPE_actual_vs_planned
# 101                0.168076
# 132                0.088042
# 148                0.116972
# 216                0.082470

# %% [markdown]
# <p>These routes will be excluded and Google Maps predictions which uses Dublin Bus static GTFS information will be used instead, unless predictions can be improved with neural network modelling.</p>
